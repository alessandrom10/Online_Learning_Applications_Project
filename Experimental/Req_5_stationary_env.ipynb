# %% [markdown]
# # Requirement 5

# %%
import numpy as np

np.set_printoptions(precision=3)

import numpy as np

class PricingEnvConversion:
    def __init__(self, mu, T, conversion_fn, n_customers=100):
        """
        mu: N x P matrix of per-unit profit (price - cost)
        I: total cumulative inventory across all rounds
        T: total number of rounds
        conversion_fn: function which for a given price index gives buying probability
        n_customers: number of potential buyers per round
        """
        self.mu = np.array(mu)
        self.T = T
        self.conversion_fn = conversion_fn
        self.n_customers = n_customers
        self.t = 0
        self.N, self.P = self.mu.shape

    def round(self, price_vector):
        if self.t >= self.T:
            raise Exception("Environment finished all rounds.")

        rewards_per_unit = np.zeros(self.N)
        demand = np.zeros(self.N, dtype=int)
        profit = np.zeros(self.N)

        for i in range(self.N):
            price_idx = price_vector[i]
            if price_idx == -1:
                # skip this product
                continue
            # compute reward and demand
            rewards_per_unit[i] = self.mu[i, price_idx]
            prob = self.conversion_fn(price_idx)
            demand[i] = np.random.binomial(self.n_customers, prob)
            profit[i] = rewards_per_unit[i] * demand[i]

        self.t += 1
        return demand, profit

# %%
from scipy import optimize


class CombinatorialUCB:
    def __init__(self, N, P, B, T):
        """
        N: number of products
        P: number of prices
        B: shared capacity (not used right now)
        """
        self.N = N
        self.P = P
        self.B = B
        self.remaining_inventory = B
        self.T = T
        self.counts = np.zeros((N, P))  # times each arm is chosen
        self.means = np.zeros((N, P))   # estimated mean rewards
        self.avg_c = np.zeros((N, P))
        self.t = 0

    def pull_arm(self):
        prices = []

        # If inventory exhausted, sell nothing
        if self.remaining_inventory < 1:
            prices = [-1] * self.N
            return prices

        if self.t < self.P:
            prices = [self.t % self.P] * self.N
            return prices

        f_ucbs = self.means + np.sqrt(2*np.log(self.t + 1)/(self.counts + 1e-6))
        c_lcbs = self.avg_c - np.sqrt(2*np.log(self.t + 1)/(self.counts + 1e-6))

        rho = self.remaining_inventory / max(1, self.T - self.t)

        # compute LP to get probabilities over product/price pairs
        gamma = self.compute_opt(f_ucbs, c_lcbs, rho)

        for i in range(self.N):
            probs = np.clip(gamma[i], 0, None)
            probs /= probs.sum()

            price_idx = np.random.choice(len(probs), p=probs)
            
            # If the sampled index is 0, treat it as "do not sell"
            if price_idx == 0:
                prices.append(-1)
            else:
                prices.append(price_idx - 1)  # shift back to match original price indices

        return prices

    
    def compute_opt(self, f_ucbs, c_lcbs, rho):
        """
        Args:
        f_ucbs: (N x P) upper confidence bounds on expected rewards
        c_lcbs: (N x P) lower confidence bounds on expected consumptions
        rho: per-round budget (remaining_inventory / remaining_time)

        Returns:
            gamma: (N x (P+1)) array of probabilities over price choices
        """
        N, P = self.N, self.P

        # Add dummy price (0 reward, 0 cost) as first column (it's equivalent to "do not sell")
        f_ucbs = np.hstack([np.zeros((N, 1)), f_ucbs])
        c_lcbs = np.hstack([np.zeros((N, 1)), c_lcbs])

        # Objective: maximize expected reward
        c_obj = -f_ucbs.flatten()

        # Bounds: gamma_ij >= 0
        bounds = (0, 1)

        # Equality constraints: sum of each row = 1
        A_eq = np.zeros((N, N * (P + 1)))
        b_eq = np.ones(N)
        for i in range(N):
            for j in range(P + 1):
                A_eq[i, i * (P + 1) + j] = 1

        # Inequality constraint: expected cost <= rho
        A_ub = [c_lcbs.flatten()]
        b_ub = [rho]

        res = optimize.linprog(c=c_obj, A_ub=A_ub, b_ub=b_ub, A_eq=A_eq, b_eq=b_eq, bounds=bounds)

        if res.success:
            gamma = res.x.reshape(N, P + 1)
        else:
            gamma = np.zeros((N, P + 1))

        return gamma



    def update(self, prices, demand, rewards):
        """
        prices: list of chosen price indices per product (-1 if product not sold)
        demand: list of units sold per product
        rewards: observed per-product reward
        """
        self.t += 1

        for i in range(self.N):
            p = prices[i]
            if p == -1:
                continue  # product not sold, skip

            units_sold = demand[i]

            # Update inventory
            self.remaining_inventory -= units_sold
            if self.remaining_inventory < 0:
                self.remaining_inventory = 0  # inventory can't go negative

            # Update estimated mean reward for this product/price pair
            self.counts[i, p] += 1
            n = self.counts[i, p]
            self.means[i, p] += (rewards[i] - self.means[i, p]) / n

            self.avg_c[i, p] += (units_sold - self.avg_c[i, p]) / n

# %%
def clairvoyant_sample_action(gamma, f):
    """
    Args:
        gamma: (N x (P+1)) array of action probabilities from the LP,
               where the first column is the "do not sell" option.
        f: (N x P) array of true expected rewards for each product/price pair.

    Returns:
        sampled_action: list of chosen price indices per product
                        (-1 indicates "do not sell").
        expected_reward_per_round: float, sum of expected rewards across products
                                   for the sampled action (already accounts for n_customers)
    """

    N, _ = gamma.shape

    sampled_action = []
    expected_reward_per_round = 0.0
    for i in range(N):
        probs = np.clip(gamma[i], 0, None)
        if probs.sum() > 0:
            probs /= probs.sum()
        else:
            probs = np.zeros_like(probs)
            probs[0] = 1  # fallback: "do not sell"
        idx = np.random.choice(len(probs), p=probs)
        if idx == 0:
            sampled_action.append(-1)
        else:
            sampled_action.append(idx-1)
            expected_reward_per_round += f[i, idx-1]

    return sampled_action, expected_reward_per_round

# %%
from collections import deque


class DualAgent:
    def __init__(self, N, P, B, T, window_size=100):
        """
        N: number of products
        P: number of prices
        B: shared capacity (total inventory)
        T: total number of rounds
        window_size: number of past rounds to keep in the sliding window
        """
        self.N = N
        self.P = P
        self.B = B
        self.T = T
        self.window_size = window_size

        self.lambda_ = 0

        self.reset()

    def reset(self):
        """Reset agent state for a new simulation"""
        self.remaining_inventory = self.B
        self.t = 0
        # Sliding window: store last window_size rounds
        self.rewards_window = deque(maxlen=self.window_size)       
        self.consumptions_window = deque(maxlen=self.window_size)  

        self.lambda_ = 0

    def pull_arm(self):
        """
        Pull arm using primal-dual approach with sliding window statistics.
        
        Parameters
        ----------
        lam : float
            Current dual variable λ (shadow price of capacity)
        
        Returns
        -------
        prices : list of int
            Selected price index for each product (-1 = not offered)
        """
        if self.remaining_inventory < 1:
            return [-1] * self.N

        # --- Compute empirical means and average consumptions from sliding window ---
        if len(self.rewards_window) == 0:
            means = np.zeros((self.N, self.P))
            avg_c = np.zeros((self.N, self.P))
            counts = np.zeros((self.N, self.P))
        else:
            rewards_stack = np.stack(self.rewards_window, axis=0)       # shape: window_size x N x P
            consumptions_stack = np.stack(self.consumptions_window, axis=0)
            counts = np.sum(rewards_stack != 0, axis=0)
            means = np.sum(rewards_stack, axis=0) / np.maximum(1, counts)
            avg_c = np.sum(consumptions_stack, axis=0) / np.maximum(1, counts)

        # --- Initial exploration: pick different price for each product ---
        if self.t < self.P:
            return [self.t % self.P for _ in range(self.N)]

        # --- Primal-dual step: compute optimal probability distribution ---
        # Use empirical means for reward and consumption, and current lambda
        if(self.t % 10 == 0):
            print("My current means is")
            print(means)
            print("My current avg_c is")
            print(avg_c)
            print("My current lambda is")
            print(self.lambda_)

        gamma = self.compute_opt(means, avg_c, self.lambda_)

        # --- Sample prices for each product from computed distribution ---
        prices = []
        for i in range(self.N):
            probs = np.clip(gamma[i], 0, None)
            probs /= probs.sum() + 1e-8  # normalize to make it a valid distribution
            choice = np.random.choice(len(probs), p=probs)
            prices.append(-1 if choice == 0 else choice - 1)  # 0 = not offered

        return prices
        
    def compute_opt(self, f_means, c_means, lambda_):
        """
        Compute optimal product/price distribution under primal-dual Lagrangian.

        Parameters
        ----------
        f_means : np.ndarray, shape (N, P)
            Empirical mean rewards for each product i and price option j
        c_means : np.ndarray, shape (N, P)
            Empirical mean consumptions (units) for each product i and price option j
        lam : float
            Current dual variable λ (shadow price of capacity)

        Returns
        -------
        policy : np.ndarray, shape (N, P+1)
            Probability distribution over actions for each product.
            Column 0 corresponds to "not offering the product".
        """
        N, P = self.N, self.P

        # Add dummy "not offering" option (zero reward, zero cost)
        f_means = np.hstack([np.zeros((N, 1)), f_means])
        c_means = np.hstack([np.zeros((N, 1)), c_means])

        # Build objective coefficients: reward minus λ * cost
        obj = (f_means - lambda_ * c_means).flatten()

        # Constraints: each product must choose exactly one action
        A_eq = np.zeros((N, N * (P + 1)))
        b_eq = np.ones(N)
        for i in range(N):
            for j in range(P + 1):
                A_eq[i, i * (P + 1) + j] = 1

        # Bounds: each variable is in [0,1]
        bounds = [(0, 1) for _ in range(N * (P + 1))]

        # Solve LP (maximize linear function → minimize negative)
        res = optimize.linprog(
            c=-obj,
            A_eq=A_eq, b_eq=b_eq,
            bounds=bounds,
            method="highs"
        )

        if res.success:
            return res.x.reshape(N, P + 1)
        else:
            # fallback: uniform distribution over all options (including "not offer")
            return np.ones((N, P + 1)) / (P + 1)
        

    def update(self, prices, demand, rewards):
        """
        Update sliding-window estimates and dual variable with observed data.

        Arguments:
            prices: list of chosen price indices per product (-1 if product not offered)
            demand: observed demand per product
            rewards: observed per-product reward
        """
        self.t += 1

        # --- Update remaining inventory ---
        total_consumed = sum(demand)
        self.remaining_inventory = max(0, self.remaining_inventory - total_consumed)

        # --- Construct this round's matrices for sliding window ---
        rewards_mat = np.zeros((self.N, self.P))
        consumption_mat = np.zeros((self.N, self.P))
        for i in range(self.N):
            p = prices[i]
            if p != -1:
                rewards_mat[i, p] = rewards[i]
                consumption_mat[i, p] = demand[i]

        # --- Append to sliding window ---
        self.rewards_window.append(rewards_mat)
        self.consumptions_window.append(consumption_mat)

        # --- Update dual variable lambda (primal-dual) ---
        # rho = per-round budget allowance
        rho = self.remaining_inventory / max(1, self.T - self.t)
        eta = 0.1 / self.N
        self.lambda_ = max(0, self.lambda_ + eta * (total_consumed - rho))

# %%
import numpy as np

# environment setup
N, P = 3, 5
B, T = 250_000, 10_000
n_customers = 20
#n_trials = 10
n_trials = 1

mu = np.array([[1, 2, 3, 4, 5],
               [2, 3, 4, 5, 6],
               [1, 3, 5, 7, 9]])

conversion_fn = lambda price_idx: max(0, 1 - 0.2*price_idx)

# Cumulative regret
all_cum_regret_ratios = np.zeros((n_trials, T))

# Expected reward per product/price per customer
f = mu * np.array([conversion_fn(p) for p in range(P)]) * n_customers

# Cost per product/price (for all customers)
c = np.array([[conversion_fn(p) for p in range(P)] for _ in range(N)]) * n_customers

agent_clar = CombinatorialUCB(N, P, B, T)
rho_clar = B / T

# LP solution: probability distribution over prices
gamma_clar = agent_clar.compute_opt(f, c, rho_clar)

for trial in range(n_trials):
    print(f"\n=== Starting Trial {trial+1} ===")

    #agent = CombinatorialUCB(N, P, B, T)
    agent = DualAgent(N=N, P=P, B=B, T=T, window_size=99999)
    env = PricingEnvConversion(mu, T, conversion_fn, n_customers=n_customers)

    total_agent_reward = 0
    total_clair_reward = 0

    for t in range(T):
        # Agent step
        agent_prices = agent.pull_arm()
        demand, rewards = env.round(agent_prices)
        agent.update(agent_prices, demand, rewards)
        total_agent_reward += rewards.sum()

        # Clairvoyant step
        clair_action, clair_reward_per_round = clairvoyant_sample_action(gamma_clar, f)
        total_clair_reward += clair_reward_per_round

        # Compute cumulative regret ratio
        cumulative_regret = total_clair_reward - total_agent_reward
        all_cum_regret_ratios[trial, t] = cumulative_regret / (t + 1)

        # Print checkpoints every 5 rounds
        if (t + 1) % 5 == 0:
            print(f"Trial {trial+1}, Round {t+1}:")
            print(f"  Clairvoyant action: {clair_action}, reward per round: {clair_reward_per_round:.2f}")
            print(f"  Agent action:       {agent_prices}, reward this round: {rewards.sum():.2f}")
            print(f"  Cumulative clairvoyant reward: {total_clair_reward:.2f}")
            print(f"  Cumulative agent reward:       {total_agent_reward:.2f}")
            print(f"  Cumulative regret: {cumulative_regret:.2f}")
            print(f"  Regret / T ratio:  {cumulative_regret / (t+1):.2f}")
            print("--------------------------------------------------")

# Final cumulative regret ratio per trial
final_ratios = all_cum_regret_ratios[:, -1]
print("\n--- Final regret/T ratio per trial ---")
for trial in range(n_trials):
    print(f"Trial {trial+1}: regret/T = {final_ratios[trial]:.2f}")
print(f"Average final regret/T over {n_trials} trials: {final_ratios.mean():.2f}")
# Out:
# === Starting Trial 1 ===
# Trial 1, Round 5:
#   Clairvoyant action: [3, 3, 3], reward per round: 128.00
#   Agent action:       [4, 4, 4], reward this round: 84.00
#   Cumulative clairvoyant reward: 656.00
#   Cumulative agent reward:       594.00
#   Cumulative regret: 62.00
#   Regret / T ratio:  12.40
# --------------------------------------------------
# Trial 1, Round 10:
#   Clairvoyant action: [3, 3, 3], reward per round: 128.00
#   Agent action:       [3, 3, 3], reward this round: 127.00
#   Cumulative clairvoyant reward: 1312.00
#   Cumulative agent reward:       1176.00
#   Cumulative regret: 136.00
#   Regret / T ratio:  13.60
# --------------------------------------------------
# My current means is
# [[20.    34.    33.    35.333 15.   ]
#  [40.    42.    46.667 46.25   6.   ]
#  [20.    48.    60.    57.75  45.   ]]
# My current avg_c is
# [[20.    17.    11.     8.833  3.   ]
#  [20.    14.    11.667  9.25   1.   ]
#  [20.    16.    12.     8.25   5.   ]]
# My current lambda is
# 1.7351576610134931
# Trial 1, Round 15:
#   Clairvoyant action: [3, 3, 3], reward per round: 128.00
#   Agent action:       [3, 3, 3], reward this round: 126.00
#   Cumulative clairvoyant reward: 1952.00
#   Cumulative agent reward:       1849.00
#   Cumulative regret: 103.00
#   Regret / T ratio:  6.87
# --------------------------------------------------
# Trial 1, Round 20:
#   Clairvoyant action: [3, 3, 3], reward per round: 128.00
#   Agent action:       [3, 3, 3], reward this round: 126.00
#   Cumulative clairvoyant reward: 2592.00
#   Cumulative agent reward:       2429.00
#   Cumulative regret: 163.00
#   Regret / T ratio:  8.15
# --------------------------------------------------
# My current means is
# [[20.    34.    33.    33.75  15.   ]
#  [40.    42.    46.667 42.857  6.   ]
#  [20.    48.    57.5   52.769 45.   ]]
# My current avg_c is
# [[20.    17.    11.     8.438  3.   ]
#  [20.    14.    11.667  8.571  1.   ]
#  [20.    16.    11.5    7.538  5.   ]]
# My current lambda is
# 1.4369103502736769
# Trial 1, Round 25:
#   Clairvoyant action: [3, 2, 3], reward per round: 136.00
#   Agent action:       [3, 2, 2], reward this round: 121.00
#   Cumulative clairvoyant reward: 3248.00
#   Cumulative agent reward:       2990.00
#   Cumulative regret: 258.00
#   Regret / T ratio:  10.32
# --------------------------------------------------
# Trial 1, Round 30:
#   Clairvoyant action: [3, 3, 3], reward per round: 128.00
#   Agent action:       [3, 3, 3], reward this round: 160.00
#   Cumulative clairvoyant reward: 3888.00
#   Cumulative agent reward:       3670.00
#   Cumulative regret: 218.00
#   Regret / T ratio:  7.27
# --------------------------------------------------
# My current means is
# [[20.    34.    33.    33.538 15.   ]
#  [40.    42.    44.    42.25   6.   ]
#  [20.    48.    55.    51.1   45.   ]]
# My current avg_c is
# [[20.    17.    11.     8.385  3.   ]
#  [20.    14.    11.     8.45   1.   ]
#  [20.    16.    11.     7.3    5.   ]]
# My current lambda is
# 1.5716004973186106
# Trial 1, Round 35:
#   Clairvoyant action: [3, 3, 3], reward per round: 128.00
#   Agent action:       [3, 3, 3], reward this round: 155.00
#   Cumulative clairvoyant reward: 4536.00
#   Cumulative agent reward:       4402.00
#   Cumulative regret: 134.00
#   Regret / T ratio:  3.83
# --------------------------------------------------
# Trial 1, Round 40:
#   Clairvoyant action: [3, 3, 3], reward per round: 128.00
#   Agent action:       [3, 3, 3], reward this round: 118.00
#   Cumulative clairvoyant reward: 5184.00
#   Cumulative agent reward:       5032.00
#   Cumulative regret: 152.00
#   Regret / T ratio:  3.80
# --------------------------------------------------
# My current means is
# [[20.    34.    33.    33.111 15.   ]
#  [40.    42.    44.    41.667  6.   ]
#  [20.    48.    55.    55.3   45.   ]]
# My current avg_c is
# [[20.    17.    11.     8.278  3.   ]
#  [20.    14.    11.     8.333  1.   ]
#  [20.    16.    11.     7.9    5.   ]]
# My current lambda is
# 1.6400234187310345
# Trial 1, Round 45:
#   Clairvoyant action: [3, 3, 3], reward per round: 128.00
#   Agent action:       [3, 3, 3], reward this round: 125.00
#   Cumulative clairvoyant reward: 5824.00
#   Cumulative agent reward:       5653.00
#   Cumulative regret: 171.00
#   Regret / T ratio:  3.80
# --------------------------------------------------
# Trial 1, Round 50:
#   Clairvoyant action: [3, 3, 3], reward per round: 128.00
#   Agent action:       [3, 2, 3], reward this round: 140.00
#   Cumulative clairvoyant reward: 6472.00
#   Cumulative agent reward:       6256.00
#   Cumulative regret: 216.00
#   Regret / T ratio:  4.32
# --------------------------------------------------
# My current means is
# [[20.    34.    33.    33.478 15.   ]
#  [40.    42.    44.889 40.526  6.   ]
#  [20.    48.    55.    53.725 45.   ]]
# My current avg_c is
# [[20.    17.    11.     8.37   3.   ]
#  [20.    14.    11.222  8.105  1.   ]
#  [20.    16.    11.     7.675  5.   ]]
# My current lambda is
# 1.2747697899089265
# Trial 1, Round 55:
#   Clairvoyant action: [3, 3, 3], reward per round: 128.00
#   Agent action:       [3, 3, 3], reward this round: 164.00
#   Cumulative clairvoyant reward: 7120.00
#   Cumulative agent reward:       6994.00
#   Cumulative regret: 126.00
#   Regret / T ratio:  2.29
# --------------------------------------------------
# Trial 1, Round 60:
#   Clairvoyant action: [3, 3, 3], reward per round: 128.00
#   Agent action:       [3, 3, 3], reward this round: 125.00
#   Cumulative clairvoyant reward: 7768.00
#   Cumulative agent reward:       7637.00
#   Cumulative regret: 131.00
#   Regret / T ratio:  2.18
# --------------------------------------------------
# My current means is
# [[20.    34.    33.    33.5   15.   ]
#  [40.    42.    46.333 41.     6.   ]
#  [20.    48.    55.    54.74  45.   ]]
# My current avg_c is
# [[20.    17.    11.     8.375  3.   ]
#  [20.    14.    11.583  8.2    1.   ]
#  [20.    16.    11.     7.82   5.   ]]
# My current lambda is
# 1.843216363524215
# Trial 1, Round 65:
#   Clairvoyant action: [3, 3, 3], reward per round: 128.00
#   Agent action:       [3, 3, 3], reward this round: 116.00
#   Cumulative clairvoyant reward: 8416.00
#   Cumulative agent reward:       8268.00
#   Cumulative regret: 148.00
#   Regret / T ratio:  2.28
# --------------------------------------------------
# Trial 1, Round 70:
#   Clairvoyant action: [3, 3, 3], reward per round: 128.00
#   Agent action:       [3, 3, 3], reward this round: 107.00
#   Cumulative clairvoyant reward: 9064.00
#   Cumulative agent reward:       8887.00
#   Cumulative regret: 177.00
#   Regret / T ratio:  2.53
# --------------------------------------------------
# My current means is
# [[20.    34.    33.    33.03  15.   ]
#  [40.    42.    46.667 40.673  6.   ]
#  [20.    48.    55.    54.483 45.   ]]
# My current avg_c is
# [[20.    17.    11.     8.258  3.   ]
#  [20.    14.    11.667  8.135  1.   ]
#  [20.    16.    11.     7.783  5.   ]]
# My current lambda is
# 1.5782742935684793
# Trial 1, Round 75:
#   Clairvoyant action: [3, 3, 3], reward per round: 128.00
#   Agent action:       [3, 2, 3], reward this round: 171.00
#   Cumulative clairvoyant reward: 9704.00
#   Cumulative agent reward:       9551.00
#   Cumulative regret: 153.00
#   Regret / T ratio:  2.04
# --------------------------------------------------
# Trial 1, Round 80:
#   Clairvoyant action: [3, 3, 3], reward per round: 128.00
#   Agent action:       [3, 2, 3], reward this round: 142.00
#   Cumulative clairvoyant reward: 10344.00
#   Cumulative agent reward:       10191.00
#   Cumulative regret: 153.00
#   Regret / T ratio:  1.91
# --------------------------------------------------
# My current means is
# [[20.    34.    33.    33.263 15.   ]
#  [40.    42.    48.182 40.     6.   ]
#  [20.    48.    55.    54.    45.   ]]
# My current avg_c is
# [[20.    17.    11.     8.316  3.   ]
#  [20.    14.    12.045  8.     1.   ]
#  [20.    16.    11.     7.714  5.   ]]
# My current lambda is
# 2.1467782213003335
# Trial 1, Round 85:
#   Clairvoyant action: [3, 2, 3], reward per round: 136.00
#   Agent action:       [3, 3, 3], reward this round: 125.00
#   Cumulative clairvoyant reward: 11000.00
#   Cumulative agent reward:       10844.00
#   Cumulative regret: 156.00
#   Regret / T ratio:  1.84
# --------------------------------------------------
# Trial 1, Round 90:
#   Clairvoyant action: [3, 2, 3], reward per round: 136.00
#   Agent action:       [3, 3, 3], reward this round: 67.00
#   Cumulative clairvoyant reward: 11656.00
#   Cumulative agent reward:       11452.00
#   Cumulative regret: 204.00
#   Regret / T ratio:  2.27
# --------------------------------------------------
# My current means is
# [[20.    34.    33.    32.93  15.   ]
#  [40.    42.    48.182 40.923  6.   ]
#  [20.    48.    55.    53.462 45.   ]]
# My current avg_c is
# [[20.    17.    11.     8.233  3.   ]
#  [20.    14.    12.045  8.185  1.   ]
#  [20.    16.    11.     7.638  5.   ]]
# My current lambda is
# 1.7822195646748444
# Trial 1, Round 95:
#   Clairvoyant action: [3, 3, 3], reward per round: 128.00
#   Agent action:       [3, 3, 3], reward this round: 157.00
#   Cumulative clairvoyant reward: 12296.00
#   Cumulative agent reward:       12115.00
#   Cumulative regret: 181.00
#   Regret / T ratio:  1.91
# --------------------------------------------------
# Trial 1, Round 100:
#   Clairvoyant action: [3, 2, 3], reward per round: 136.00
#   Agent action:       [3, 3, 3], reward this round: 118.00
#   Cumulative clairvoyant reward: 12960.00
#   Cumulative agent reward:       12699.00
#   Cumulative regret: 261.00
#   Regret / T ratio:  2.61
# --------------------------------------------------
# My current means is
# [[20.    34.    33.    32.75  15.   ]
#  [40.    42.    48.429 41.014  6.   ]
#  [20.    48.    55.    52.733 45.   ]]
# My current avg_c is
# [[20.    17.    11.     8.188  3.   ]
#  [20.    14.    12.107  8.203  1.   ]
#  [20.    16.    11.     7.533  5.   ]]
# My current lambda is
# 1.884154715724487
# Trial 1, Round 105:
#   Clairvoyant action: [3, 2, 3], reward per round: 136.00
#   Agent action:       [3, 3, 3], reward this round: 112.00
#   Cumulative clairvoyant reward: 13616.00
#   Cumulative agent reward:       13393.00
#   Cumulative regret: 223.00
#   Regret / T ratio:  2.12
# --------------------------------------------------
# Trial 1, Round 110:
#   Clairvoyant action: [3, 3, 3], reward per round: 128.00
#   Agent action:       [3, 3, 3], reward this round: 140.00
#   Cumulative clairvoyant reward: 14272.00
#   Cumulative agent reward:       14057.00
#   Cumulative regret: 215.00
#   Regret / T ratio:  1.95
# --------------------------------------------------
# My current means is
# [[20.    34.    33.    32.453 15.   ]
#  [40.    42.    48.552 41.154  6.   ]
#  [20.    48.    55.    53.76  45.   ]]
# My current avg_c is
# [[20.    17.    11.     8.113  3.   ]
#  [20.    14.    12.138  8.231  1.   ]
#  [20.    16.    11.     7.68   5.   ]]
# My current lambda is
# 1.9862703496290333
# Trial 1, Round 115:
#   Clairvoyant action: [3, 3, 3], reward per round: 128.00
#   Agent action:       [3, 2, 3], reward this round: 128.00
#   Cumulative clairvoyant reward: 14920.00
#   Cumulative agent reward:       14690.00
#   Cumulative regret: 230.00
#   Regret / T ratio:  2.00
# --------------------------------------------------
# Trial 1, Round 120:
#   Clairvoyant action: [3, 2, 3], reward per round: 136.00
#   Agent action:       [3, 3, 3], reward this round: 98.00
#   Cumulative clairvoyant reward: 15576.00
#   Cumulative agent reward:       15348.00
#   Cumulative regret: 228.00
#   Regret / T ratio:  1.90
# --------------------------------------------------
# My current means is
# [[20.    34.    33.    32.345 15.   ]
#  [40.    42.    48.387 41.047  6.   ]
#  [20.    48.    55.    54.027 45.   ]]
# My current avg_c is
# [[20.    17.    11.     8.086  3.   ]
#  [20.    14.    12.097  8.209  1.   ]
#  [20.    16.    11.     7.718  5.   ]]
# My current lambda is
# 1.8548794515863853
# Trial 1, Round 125:
#   Clairvoyant action: [3, 2, 3], reward per round: 136.00
#   Agent action:       [3, 3, 3], reward this round: 160.00
#   Cumulative clairvoyant reward: 16224.00
#   Cumulative agent reward:       16025.00
#   Cumulative regret: 199.00
#   Regret / T ratio:  1.59
# --------------------------------------------------
# Trial 1, Round 130:
#   Clairvoyant action: [3, 3, 3], reward per round: 128.00
#   Agent action:       [3, 3, 3], reward this round: 132.00
#   Cumulative clairvoyant reward: 16872.00
#   Cumulative agent reward:       16689.00
#   Cumulative regret: 183.00
#   Regret / T ratio:  1.41
# --------------------------------------------------
# My current means is
# [[20.    34.    33.    32.413 15.   ]
#  [40.    42.    48.75  41.842  6.   ]
#  [20.    48.    55.    53.725 45.   ]]
# My current avg_c is
# [[20.    17.    11.     8.103  3.   ]
#  [20.    14.    12.188  8.368  1.   ]
#  [20.    16.    11.     7.675  5.   ]]
# My current lambda is
# 2.156935268636242
# Trial 1, Round 135:
#   Clairvoyant action: [3, 2, 3], reward per round: 136.00
#   Agent action:       [3, 3, 3], reward this round: 124.00
#   Cumulative clairvoyant reward: 17528.00
#   Cumulative agent reward:       17332.00
#   Cumulative regret: 196.00
#   Regret / T ratio:  1.45
# --------------------------------------------------
# Trial 1, Round 140:
#   Clairvoyant action: [3, 3, 3], reward per round: 128.00
#   Agent action:       [3, 3, 3], reward this round: 138.00
#   Cumulative clairvoyant reward: 18168.00
#   Cumulative agent reward:       18031.00
#   Cumulative regret: 137.00
#   Regret / T ratio:  0.98
# --------------------------------------------------
# My current means is
# [[20.    34.    33.    32.559 15.   ]
#  [40.    42.    48.75  41.762  6.   ]
#  [20.    48.    55.    54.115 45.   ]]
# My current avg_c is
# [[20.    17.    11.     8.14   3.   ]
#  [20.    14.    12.188  8.352  1.   ]
#  [20.    16.    11.     7.731  5.   ]]
# My current lambda is
# 2.2256902284786433
# Trial 1, Round 145:
#   Clairvoyant action: [3, 3, 3], reward per round: 128.00
#   Agent action:       [3, 3, 3], reward this round: 128.00
#   Cumulative clairvoyant reward: 18824.00
#   Cumulative agent reward:       18670.00
#   Cumulative regret: 154.00
#   Regret / T ratio:  1.06
# --------------------------------------------------
# Trial 1, Round 150:
#   Clairvoyant action: [3, 3, 3], reward per round: 128.00
#   Agent action:       [3, 2, 3], reward this round: 173.00
#   Cumulative clairvoyant reward: 19488.00
#   Cumulative agent reward:       19323.00
#   Cumulative regret: 165.00
#   Regret / T ratio:  1.10
# --------------------------------------------------
# My current means is
# [[20.    34.    33.    32.603 15.   ]
#  [40.    42.    48.848 41.579  6.   ]
#  [20.    48.    55.    54.2   45.   ]]
# My current avg_c is
# [[20.    17.    11.     8.151  3.   ]
#  [20.    14.    12.212  8.316  1.   ]
#  [20.    16.    11.     7.743  5.   ]]
# My current lambda is
# 2.0943897884727747
# Trial 1, Round 155:
#   Clairvoyant action: [3, 3, 3], reward per round: 128.00
#   Agent action:       [3, 2, 3], reward this round: 111.00
#   Cumulative clairvoyant reward: 20136.00
#   Cumulative agent reward:       19895.00
#   Cumulative regret: 241.00
#   Regret / T ratio:  1.55
# --------------------------------------------------
# Trial 1, Round 160:
#   Clairvoyant action: [3, 2, 3], reward per round: 136.00
#   Agent action:       [3, 3, 3], reward this round: 116.00
#   Cumulative clairvoyant reward: 20800.00
#   Cumulative agent reward:       20623.00
#   Cumulative regret: 177.00
#   Regret / T ratio:  1.11
# --------------------------------------------------
# My current means is
# [[20.    34.    33.    32.59  15.   ]
#  [40.    42.    49.081 41.208  6.   ]
#  [20.    48.    55.    54.367 45.   ]]
# My current avg_c is
# [[20.    17.    11.     8.147  3.   ]
#  [20.    14.    12.27   8.242  1.   ]
#  [20.    16.    11.     7.767  5.   ]]
# My current lambda is
# 2.229707352424154
# Trial 1, Round 165:
#   Clairvoyant action: [3, 3, 3], reward per round: 128.00
#   Agent action:       [3, 3, 3], reward this round: 151.00
#   Cumulative clairvoyant reward: 21448.00
#   Cumulative agent reward:       21335.00
#   Cumulative regret: 113.00
#   Regret / T ratio:  0.68
# --------------------------------------------------
# Trial 1, Round 170:
#   Clairvoyant action: [3, 3, 3], reward per round: 128.00
#   Agent action:       [3, 3, 3], reward this round: 104.00
#   Cumulative clairvoyant reward: 22096.00
#   Cumulative agent reward:       21950.00
#   Cumulative regret: 146.00
#   Regret / T ratio:  0.86
# --------------------------------------------------
# My current means is
# [[20.    34.    33.    32.699 15.   ]
#  [40.    42.    49.081 41.077  6.   ]
#  [20.    48.    55.    54.644 45.   ]]
# My current avg_c is
# [[20.    17.    11.     8.175  3.   ]
#  [20.    14.    12.27   8.215  1.   ]
#  [20.    16.    11.     7.806  5.   ]]
# My current lambda is
# 2.1987296783812855
# Trial 1, Round 175:
#   Clairvoyant action: [3, 3, 3], reward per round: 128.00
#   Agent action:       [3, 2, 3], reward this round: 129.00
#   Cumulative clairvoyant reward: 22744.00
#   Cumulative agent reward:       22570.00
#   Cumulative regret: 174.00
#   Regret / T ratio:  0.99
# --------------------------------------------------
# Trial 1, Round 180:
#   Clairvoyant action: [3, 3, 3], reward per round: 128.00
#   Agent action:       [3, 3, 3], reward this round: 164.00
#   Cumulative clairvoyant reward: 23384.00
#   Cumulative agent reward:       23269.00
#   Cumulative regret: 115.00
#   Regret / T ratio:  0.64
# --------------------------------------------------
# My current means is
# [[20.    34.    33.    32.5   15.   ]
#  [40.    42.    49.5   41.496  6.   ]
#  [20.    48.    55.    54.476 45.   ]]
# My current avg_c is
# [[20.    17.    11.     8.125  3.   ]
#  [20.    14.    12.375  8.299  1.   ]
#  [20.    16.    11.     7.782  5.   ]]
# My current lambda is
# 2.4341700168110094
# Trial 1, Round 185:
#   Clairvoyant action: [3, 2, 3], reward per round: 136.00
#   Agent action:       [3, 3, 3], reward this round: 137.00
#   Cumulative clairvoyant reward: 24040.00
#   Cumulative agent reward:       23973.00
#   Cumulative regret: 67.00
#   Regret / T ratio:  0.36
# --------------------------------------------------
# Trial 1, Round 190:
#   Clairvoyant action: [3, 2, 3], reward per round: 136.00
#   Agent action:       [3, 3, 3], reward this round: 118.00
#   Cumulative clairvoyant reward: 24696.00
#   Cumulative agent reward:       24617.00
#   Cumulative regret: 79.00
#   Regret / T ratio:  0.42
# --------------------------------------------------
# My current means is
# [[20.    34.    33.    32.452 15.   ]
#  [40.    42.    49.5   41.599  6.   ]
#  [20.    48.    55.    54.794 45.   ]]
# My current avg_c is
# [[20.    17.    11.     8.113  3.   ]
#  [20.    14.    12.375  8.32   1.   ]
#  [20.    16.    11.     7.828  5.   ]]
# My current lambda is
# 2.470118541043779
# Trial 1, Round 195:
#   Clairvoyant action: [3, 3, 3], reward per round: 128.00
#   Agent action:       [3, 3, 3], reward this round: 138.00
#   Cumulative clairvoyant reward: 25336.00
#   Cumulative agent reward:       25248.00
#   Cumulative regret: 88.00
#   Regret / T ratio:  0.45
# --------------------------------------------------
# Trial 1, Round 200:
#   Clairvoyant action: [3, 3, 3], reward per round: 128.00
#   Agent action:       [3, 3, 3], reward this round: 107.00
#   Cumulative clairvoyant reward: 25976.00
#   Cumulative agent reward:       25914.00
#   Cumulative regret: 62.00
#   Regret / T ratio:  0.31
# --------------------------------------------------
# My current means is
# [[20.    34.    33.    32.592 15.   ]
#  [40.    42.    49.5   41.401  6.   ]
#  [20.    48.    55.    54.858 45.   ]]
# My current avg_c is
# [[20.    17.    11.     8.148  3.   ]
#  [20.    14.    12.375  8.28   1.   ]
#  [20.    16.    11.     7.837  5.   ]]
# My current lambda is
# 2.3057195537871342
# Trial 1, Round 205:
#   Clairvoyant action: [3, 3, 3], reward per round: 128.00
#   Agent action:       [3, 3, 3], reward this round: 135.00
#   Cumulative clairvoyant reward: 26632.00
#   Cumulative agent reward:       26584.00
#   Cumulative regret: 48.00
#   Regret / T ratio:  0.23
# --------------------------------------------------
# Trial 1, Round 210:
#   Clairvoyant action: [3, 2, 3], reward per round: 136.00
#   Agent action:       [3, 3, 3], reward this round: 162.00
#   Cumulative clairvoyant reward: 27288.00
#   Cumulative agent reward:       27298.00
#   Cumulative regret: -10.00
#   Regret / T ratio:  -0.05
# --------------------------------------------------
# My current means is
# [[20.    34.    33.    32.544 15.   ]
#  [40.    42.    49.5   41.587  6.   ]
#  [20.    48.    55.    55.23  45.   ]]
# My current avg_c is
# [[20.    17.    11.     8.136  3.   ]
#  [20.    14.    12.375  8.317  1.   ]
#  [20.    16.    11.     7.89   5.   ]]
# My current lambda is
# 2.54135010727475
# Trial 1, Round 215:
#   Clairvoyant action: [3, 3, 3], reward per round: 128.00
#   Agent action:       [3, 3, 3], reward this round: 151.00
#   Cumulative clairvoyant reward: 27928.00
#   Cumulative agent reward:       27940.00
#   Cumulative regret: -12.00
#   Regret / T ratio:  -0.06
# --------------------------------------------------
# Trial 1, Round 220:
#   Clairvoyant action: [3, 3, 3], reward per round: 128.00
#   Agent action:       [3, 2, 3], reward this round: 147.00
#   Cumulative clairvoyant reward: 28576.00
#   Cumulative agent reward:       28568.00
#   Cumulative regret: 8.00
#   Regret / T ratio:  0.04
# --------------------------------------------------
# My current means is
# [[20.    34.    33.    32.315 15.   ]
#  [40.    42.    49.659 41.25   6.   ]
#  [20.    48.    55.    55.567 45.   ]]
# My current avg_c is
# [[20.    17.    11.     8.079  3.   ]
#  [20.    14.    12.415  8.25   1.   ]
#  [20.    16.    11.     7.938  5.   ]]
# My current lambda is
# 2.0435576298358358
# Trial 1, Round 225:
#   Clairvoyant action: [3, 2, 3], reward per round: 136.00
#   Agent action:       [3, 3, 3], reward this round: 166.00
#   Cumulative clairvoyant reward: 29240.00
#   Cumulative agent reward:       29300.00
#   Cumulative regret: -60.00
#   Regret / T ratio:  -0.27
# --------------------------------------------------
# Trial 1, Round 230:
#   Clairvoyant action: [3, 2, 3], reward per round: 136.00
#   Agent action:       [3, 3, 3], reward this round: 168.00
#   Cumulative clairvoyant reward: 29896.00
#   Cumulative agent reward:       29917.00
#   Cumulative regret: -21.00
#   Regret / T ratio:  -0.09
# --------------------------------------------------
# My current means is
# [[20.    34.    33.    32.248 15.   ]
#  [40.    42.    49.619 41.432  6.   ]
#  [20.    48.    55.    55.714 45.   ]]
# My current avg_c is
# [[20.    17.    11.     8.062  3.   ]
#  [20.    14.    12.405  8.286  1.   ]
#  [20.    16.    11.     7.959  5.   ]]
# My current lambda is
# 2.179134905421433
# Trial 1, Round 235:
#   Clairvoyant action: [3, 3, 3], reward per round: 128.00
#   Agent action:       [3, 3, 3], reward this round: 121.00
#   Cumulative clairvoyant reward: 30544.00
#   Cumulative agent reward:       30581.00
#   Cumulative regret: -37.00
#   Regret / T ratio:  -0.16
# --------------------------------------------------
# Trial 1, Round 240:
#   Clairvoyant action: [3, 3, 3], reward per round: 128.00
#   Agent action:       [3, 3, 3], reward this round: 135.00
#   Cumulative clairvoyant reward: 31184.00
#   Cumulative agent reward:       31285.00
#   Cumulative regret: -101.00
#   Regret / T ratio:  -0.42
# --------------------------------------------------
# My current means is
# [[20.    34.    33.    32.542 15.   ]
#  [40.    42.    49.767 41.186  6.   ]
#  [20.    48.    55.    55.878 45.   ]]
# My current avg_c is
# [[20.    17.    11.     8.136  3.   ]
#  [20.    14.    12.442  8.237  1.   ]
#  [20.    16.    11.     7.983  5.   ]]
# My current lambda is
# 2.581452857624033
# Trial 1, Round 245:
#   Clairvoyant action: [3, 3, 3], reward per round: 128.00
#   Agent action:       [3, 2, 3], reward this round: 150.00
#   Cumulative clairvoyant reward: 31832.00
#   Cumulative agent reward:       31884.00
#   Cumulative regret: -52.00
#   Regret / T ratio:  -0.21
# --------------------------------------------------
# Trial 1, Round 250:
#   Clairvoyant action: [3, 3, 3], reward per round: 128.00
#   Agent action:       [3, 2, 3], reward this round: 104.00
#   Cumulative clairvoyant reward: 32480.00
#   Cumulative agent reward:       32443.00
#   Cumulative regret: 37.00
#   Regret / T ratio:  0.15
# --------------------------------------------------
# My current means is
# [[20.    34.    33.    32.407 15.   ]
#  [40.    42.    49.362 41.     6.   ]
#  [20.    48.    55.    55.533 45.   ]]
# My current avg_c is
# [[20.    17.    11.     8.102  3.   ]
#  [20.    14.    12.34   8.2    1.   ]
#  [20.    16.    11.     7.933  5.   ]]
# My current lambda is
# 1.850227893335096
# Trial 1, Round 255:
#   Clairvoyant action: [3, 2, 3], reward per round: 136.00
#   Agent action:       [3, 3, 3], reward this round: 103.00
#   Cumulative clairvoyant reward: 33144.00
#   Cumulative agent reward:       33154.00
#   Cumulative regret: -10.00
#   Regret / T ratio:  -0.04
# --------------------------------------------------
# Trial 1, Round 260:
#   Clairvoyant action: [3, 3, 3], reward per round: 128.00
#   Agent action:       [3, 3, 3], reward this round: 108.00
#   Cumulative clairvoyant reward: 33792.00
#   Cumulative agent reward:       33821.00
#   Cumulative regret: -29.00
#   Regret / T ratio:  -0.11
# --------------------------------------------------
# My current means is
# [[20.    34.    33.    32.547 15.   ]
#  [40.    42.    49.25  40.981  6.   ]
#  [20.    48.    55.    55.748 45.   ]]
# My current avg_c is
# [[20.    17.    11.     8.137  3.   ]
#  [20.    14.    12.312  8.196  1.   ]
#  [20.    16.    11.     7.964  5.   ]]
# My current lambda is
# 2.2191830571165942
# Trial 1, Round 265:
#   Clairvoyant action: [3, 3, 3], reward per round: 128.00
#   Agent action:       [3, 3, 3], reward this round: 124.00
#   Cumulative clairvoyant reward: 34440.00
#   Cumulative agent reward:       34457.00
#   Cumulative regret: -17.00
#   Regret / T ratio:  -0.06
# --------------------------------------------------
# Trial 1, Round 270:
#   Clairvoyant action: [3, 3, 3], reward per round: 128.00
#   Agent action:       [3, 2, 3], reward this round: 149.00
#   Cumulative clairvoyant reward: 35088.00
#   Cumulative agent reward:       35116.00
#   Cumulative regret: -28.00
#   Regret / T ratio:  -0.10
# --------------------------------------------------
# My current means is
# [[20.    34.    33.    32.361 15.   ]
#  [40.    42.    49.647 40.903  6.   ]
#  [20.    48.    55.    55.838 45.   ]]
# My current avg_c is
# [[20.    17.    11.     8.09   3.   ]
#  [20.    14.    12.412  8.181  1.   ]
#  [20.    16.    11.     7.977  5.   ]]
# My current lambda is
# 2.1546017481430613
# Trial 1, Round 275:
#   Clairvoyant action: [3, 3, 3], reward per round: 128.00
#   Agent action:       [3, 2, 3], reward this round: 115.00
#   Cumulative clairvoyant reward: 35736.00
#   Cumulative agent reward:       35724.00
#   Cumulative regret: 12.00
#   Regret / T ratio:  0.04
# --------------------------------------------------
# Trial 1, Round 280:
#   Clairvoyant action: [3, 2, 3], reward per round: 136.00
#   Agent action:       [3, 3, 3], reward this round: 132.00
#   Cumulative clairvoyant reward: 36400.00
#   Cumulative agent reward:       36397.00
#   Cumulative regret: 3.00
#   Regret / T ratio:  0.01
# --------------------------------------------------
# My current means is
# [[20.    34.    33.    32.362 15.   ]
#  [40.    42.    49.5   40.656  6.   ]
#  [20.    48.    55.    55.87  45.   ]]
# My current avg_c is
# [[20.    17.    11.     8.091  3.   ]
#  [20.    14.    12.375  8.131  1.   ]
#  [20.    16.    11.     7.981  5.   ]]
# My current lambda is
# 2.223349090652597
# Trial 1, Round 285:
#   Clairvoyant action: [3, 2, 3], reward per round: 136.00
#   Agent action:       [3, 3, 3], reward this round: 134.00
#   Cumulative clairvoyant reward: 37048.00
#   Cumulative agent reward:       37149.00
#   Cumulative regret: -101.00
#   Regret / T ratio:  -0.35
# --------------------------------------------------
# Trial 1, Round 290:
#   Clairvoyant action: [3, 3, 3], reward per round: 128.00
#   Agent action:       [3, 2, 3], reward this round: 154.00
#   Cumulative clairvoyant reward: 37696.00
#   Cumulative agent reward:       37753.00
#   Cumulative regret: -57.00
#   Regret / T ratio:  -0.20
# --------------------------------------------------
# My current means is
# [[20.    34.    33.    32.196 15.   ]
#  [40.    42.    49.614 40.717  6.   ]
#  [20.    48.    55.    56.175 45.   ]]
# My current avg_c is
# [[20.    17.    11.     8.049  3.   ]
#  [20.    14.    12.404  8.143  1.   ]
#  [20.    16.    11.     8.025  5.   ]]
# My current lambda is
# 2.2590945917943417
# Trial 1, Round 295:
#   Clairvoyant action: [3, 3, 3], reward per round: 128.00
#   Agent action:       [3, 3, 3], reward this round: 104.00
#   Cumulative clairvoyant reward: 38344.00
#   Cumulative agent reward:       38363.00
#   Cumulative regret: -19.00
#   Regret / T ratio:  -0.06
# --------------------------------------------------
# Trial 1, Round 300:
#   Clairvoyant action: [3, 3, 3], reward per round: 128.00
#   Agent action:       [3, 3, 3], reward this round: 119.00
#   Cumulative clairvoyant reward: 39000.00
#   Cumulative agent reward:       39036.00
#   Cumulative regret: -36.00
#   Regret / T ratio:  -0.12
# --------------------------------------------------
# My current means is
# [[20.    34.    33.    32.257 15.   ]
#  [40.    42.    49.559 40.525  6.   ]
#  [20.    48.    55.    56.193 45.   ]]
# My current avg_c is
# [[20.    17.    11.     8.064  3.   ]
#  [20.    14.    12.39   8.105  1.   ]
#  [20.    16.    11.     8.028  5.   ]]
# My current lambda is
# 2.1279629826566278
# Trial 1, Round 305:
#   Clairvoyant action: [3, 2, 3], reward per round: 136.00
#   Agent action:       [3, 3, 3], reward this round: 112.00
#   Cumulative clairvoyant reward: 39664.00
#   Cumulative agent reward:       39696.00
#   Cumulative regret: -32.00
#   Regret / T ratio:  -0.10
# --------------------------------------------------
# Trial 1, Round 310:
#   Clairvoyant action: [3, 2, 3], reward per round: 136.00
#   Agent action:       [3, 3, 3], reward this round: 87.00
#   Cumulative clairvoyant reward: 40328.00
#   Cumulative agent reward:       40290.00
#   Cumulative regret: 38.00
#   Regret / T ratio:  0.12
# --------------------------------------------------
# My current means is
# [[20.    34.    33.    32.248 15.   ]
#  [40.    42.    49.29  40.327  6.   ]
#  [20.    48.    55.    56.21  45.   ]]
# My current avg_c is
# [[20.    17.    11.     8.062  3.   ]
#  [20.    14.    12.323  8.065  1.   ]
#  [20.    16.    11.     8.03   5.   ]]
# My current lambda is
# 1.8300638096484145
# Trial 1, Round 315:
#   Clairvoyant action: [3, 3, 3], reward per round: 128.00
#   Agent action:       [3, 3, 3], reward this round: 123.00
#   Cumulative clairvoyant reward: 40992.00
#   Cumulative agent reward:       40991.00
#   Cumulative regret: 1.00
#   Regret / T ratio:  0.00
# --------------------------------------------------
# Trial 1, Round 320:
#   Clairvoyant action: [3, 3, 3], reward per round: 128.00
#   Agent action:       [3, 2, 3], reward this round: 118.00
#   Cumulative clairvoyant reward: 41640.00
#   Cumulative agent reward:       41601.00
#   Cumulative regret: 39.00
#   Regret / T ratio:  0.12
# --------------------------------------------------
# My current means is
# [[20.    34.    33.    32.304 15.   ]
#  [40.    42.    49.169 40.198  6.   ]
#  [20.    48.    55.    56.271 45.   ]]
# My current avg_c is
# [[20.    17.    11.     8.076  3.   ]
#  [20.    14.    12.292  8.04   1.   ]
#  [20.    16.    11.     8.039  5.   ]]
# My current lambda is
# 1.9321771304216528
# Trial 1, Round 325:
#   Clairvoyant action: [3, 3, 3], reward per round: 128.00
#   Agent action:       [3, 3, 3], reward this round: 157.00
#   Cumulative clairvoyant reward: 42280.00
#   Cumulative agent reward:       42293.00
#   Cumulative regret: -13.00
#   Regret / T ratio:  -0.04
# --------------------------------------------------
# Trial 1, Round 330:
#   Clairvoyant action: [3, 3, 3], reward per round: 128.00
#   Agent action:       [3, 2, 3], reward this round: 162.00
#   Cumulative clairvoyant reward: 42920.00
#   Cumulative agent reward:       42922.00
#   Cumulative regret: -2.00
#   Regret / T ratio:  -0.01
# --------------------------------------------------
# My current means is
# [[20.    34.    33.    32.429 15.   ]
#  [40.    42.    49.043 40.019  6.   ]
#  [20.    48.    55.    56.306 45.   ]]
# My current avg_c is
# [[20.    17.    11.     8.107  3.   ]
#  [20.    14.    12.261  8.004  1.   ]
#  [20.    16.    11.     8.044  5.   ]]
# My current lambda is
# 2.234371912536434
# Trial 1, Round 335:
#   Clairvoyant action: [3, 3, 3], reward per round: 128.00
#   Agent action:       [3, 3, 3], reward this round: 129.00
#   Cumulative clairvoyant reward: 43568.00
#   Cumulative agent reward:       43588.00
#   Cumulative regret: -20.00
#   Regret / T ratio:  -0.06
# --------------------------------------------------
# Trial 1, Round 340:
#   Clairvoyant action: [3, 3, 3], reward per round: 128.00
#   Agent action:       [3, 2, 3], reward this round: 122.00
#   Cumulative clairvoyant reward: 44216.00
#   Cumulative agent reward:       44204.00
#   Cumulative regret: 12.00
#   Regret / T ratio:  0.04
# --------------------------------------------------
# My current means is
# [[20.    34.    33.    32.405 15.   ]
#  [40.    42.    49.029 40.169  6.   ]
#  [20.    48.    55.    56.17  45.   ]]
# My current avg_c is
# [[20.    17.    11.     8.101  3.   ]
#  [20.    14.    12.257  8.034  1.   ]
#  [20.    16.    11.     8.024  5.   ]]
# My current lambda is
# 2.0699781309451732
# Trial 1, Round 345:
#   Clairvoyant action: [3, 3, 3], reward per round: 128.00
#   Agent action:       [3, 3, 3], reward this round: 132.00
#   Cumulative clairvoyant reward: 44864.00
#   Cumulative agent reward:       44885.00
#   Cumulative regret: -21.00
#   Regret / T ratio:  -0.06
# --------------------------------------------------
# Trial 1, Round 350:
#   Clairvoyant action: [3, 3, 3], reward per round: 128.00
#   Agent action:       [3, 3, 3], reward this round: 108.00
#   Cumulative clairvoyant reward: 45512.00
#   Cumulative agent reward:       45535.00
#   Cumulative regret: -23.00
#   Regret / T ratio:  -0.07
# --------------------------------------------------
# My current means is
# [[20.    34.    33.    32.416 15.   ]
#  [40.    42.    49.222 40.127  6.   ]
#  [20.    48.    55.    56.226 45.   ]]
# My current avg_c is
# [[20.    17.    11.     8.104  3.   ]
#  [20.    14.    12.306  8.025  1.   ]
#  [20.    16.    11.     8.032  5.   ]]
# My current lambda is
# 2.2388889952888036
# Trial 1, Round 355:
#   Clairvoyant action: [3, 3, 3], reward per round: 128.00
#   Agent action:       [3, 2, 3], reward this round: 165.00
#   Cumulative clairvoyant reward: 46160.00
#   Cumulative agent reward:       46184.00
#   Cumulative regret: -24.00
#   Regret / T ratio:  -0.07
# --------------------------------------------------
# Trial 1, Round 360:
#   Clairvoyant action: [3, 3, 3], reward per round: 128.00
#   Agent action:       [3, 3, 3], reward this round: 152.00
#   Cumulative clairvoyant reward: 46808.00
#   Cumulative agent reward:       46882.00
#   Cumulative regret: -74.00
#   Regret / T ratio:  -0.21
# --------------------------------------------------
# My current means is
# [[20.    34.    33.    32.483 15.   ]
#  [40.    42.    49.351 40.088  6.   ]
#  [20.    48.    55.    56.28  45.   ]]
# My current avg_c is
# [[20.    17.    11.     8.121  3.   ]
#  [20.    14.    12.338  8.018  1.   ]
#  [20.    16.    11.     8.04   5.   ]]
# My current lambda is
# 2.5411735812784264
# Trial 1, Round 365:
#   Clairvoyant action: [3, 3, 3], reward per round: 128.00
#   Agent action:       [3, 3, 3], reward this round: 122.00
#   Cumulative clairvoyant reward: 47456.00
#   Cumulative agent reward:       47533.00
#   Cumulative regret: -77.00
#   Regret / T ratio:  -0.21
# --------------------------------------------------
# Trial 1, Round 370:
#   Clairvoyant action: [3, 2, 3], reward per round: 136.00
#   Agent action:       [3, 2, 3], reward this round: 125.00
#   Cumulative clairvoyant reward: 48112.00
#   Cumulative agent reward:       48131.00
#   Cumulative regret: -19.00
#   Regret / T ratio:  -0.05
# --------------------------------------------------
# My current means is
# [[20.    34.    33.    32.372 15.   ]
#  [40.    42.    49.158 40.137  6.   ]
#  [20.    48.    55.    56.233 45.   ]]
# My current avg_c is
# [[20.    17.    11.     8.093  3.   ]
#  [20.    14.    12.289  8.027  1.   ]
#  [20.    16.    11.     8.033  5.   ]]
# My current lambda is
# 2.110189382314527
# Trial 1, Round 375:
#   Clairvoyant action: [3, 3, 3], reward per round: 128.00
#   Agent action:       [3, 3, 3], reward this round: 95.00
#   Cumulative clairvoyant reward: 48760.00
#   Cumulative agent reward:       48816.00
#   Cumulative regret: -56.00
#   Regret / T ratio:  -0.15
# --------------------------------------------------
# Trial 1, Round 380:
#   Clairvoyant action: [3, 2, 3], reward per round: 136.00
#   Agent action:       [3, 3, 3], reward this round: 141.00
#   Cumulative clairvoyant reward: 49424.00
#   Cumulative agent reward:       49442.00
#   Cumulative regret: -18.00
#   Regret / T ratio:  -0.05
# --------------------------------------------------
# My current means is
# [[20.    34.    33.    32.436 15.   ]
#  [40.    42.    49.282 40.284  6.   ]
#  [20.    48.    55.    56.038 45.   ]]
# My current avg_c is
# [[20.    17.    11.     8.109  3.   ]
#  [20.    14.    12.321  8.057  1.   ]
#  [20.    16.    11.     8.005  5.   ]]
# My current lambda is
# 2.3458847271261365
# Trial 1, Round 385:
#   Clairvoyant action: [3, 3, 3], reward per round: 128.00
#   Agent action:       [3, 3, 3], reward this round: 119.00
#   Cumulative clairvoyant reward: 50072.00
#   Cumulative agent reward:       50049.00
#   Cumulative regret: 23.00
#   Regret / T ratio:  0.06
# --------------------------------------------------
# Trial 1, Round 390:
#   Clairvoyant action: [3, 3, 3], reward per round: 128.00
#   Agent action:       [3, 3, 3], reward this round: 148.00
#   Cumulative clairvoyant reward: 50720.00
#   Cumulative agent reward:       50736.00
#   Cumulative regret: -16.00
#   Regret / T ratio:  -0.04
# --------------------------------------------------
# My current means is
# [[20.    34.    33.    32.332 15.   ]
#  [40.    42.    49.61  40.279  6.   ]
#  [20.    48.    55.    56.    45.   ]]
# My current avg_c is
# [[20.    17.    11.     8.083  3.   ]
#  [20.    14.    12.402  8.056  1.   ]
#  [20.    16.    11.     8.     5.   ]]
# My current lambda is
# 2.448058552738927
# Trial 1, Round 395:
#   Clairvoyant action: [3, 3, 3], reward per round: 128.00
#   Agent action:       [3, 3, 3], reward this round: 144.00
#   Cumulative clairvoyant reward: 51368.00
#   Cumulative agent reward:       51468.00
#   Cumulative regret: -100.00
#   Regret / T ratio:  -0.25
# --------------------------------------------------
# Trial 1, Round 400:
#   Clairvoyant action: [3, 3, 3], reward per round: 128.00
#   Agent action:       [3, 3, 3], reward this round: 116.00
#   Cumulative clairvoyant reward: 52016.00
#   Cumulative agent reward:       52097.00
#   Cumulative regret: -81.00
#   Regret / T ratio:  -0.20
# --------------------------------------------------
# My current means is
# [[20.    34.    33.    32.485 15.   ]
#  [40.    42.    49.61  40.413  6.   ]
#  [20.    48.    55.    55.928 45.   ]]
# My current avg_c is
# [[20.    17.    11.     8.121  3.   ]
#  [20.    14.    12.402  8.083  1.   ]
#  [20.    16.    11.     7.99   5.   ]]
# My current lambda is
# 2.817553806736442
# Trial 1, Round 405:
#   Clairvoyant action: [3, 3, 3], reward per round: 128.00
#   Agent action:       [3, 3, 3], reward this round: 154.00
#   Cumulative clairvoyant reward: 52656.00
#   Cumulative agent reward:       52764.00
#   Cumulative regret: -108.00
#   Regret / T ratio:  -0.27
# --------------------------------------------------
# Trial 1, Round 410:
#   Clairvoyant action: [3, 3, 3], reward per round: 128.00
#   Agent action:       [3, 2, 3], reward this round: 161.00
#   Cumulative clairvoyant reward: 53296.00
#   Cumulative agent reward:       53351.00
#   Cumulative regret: -55.00
#   Regret / T ratio:  -0.13
# --------------------------------------------------
# My current means is
# [[20.    34.    33.    32.414 15.   ]
#  [40.    42.    49.735 40.463  6.   ]
#  [20.    48.    55.    55.825 45.   ]]
# My current avg_c is
# [[20.    17.    11.     8.103  3.   ]
#  [20.    14.    12.434  8.093  1.   ]
#  [20.    16.    11.     7.975  5.   ]]
# My current lambda is
# 2.453485797051061
# Trial 1, Round 415:
#   Clairvoyant action: [3, 3, 3], reward per round: 128.00
#   Agent action:       [3, 3, 3], reward this round: 96.00
#   Cumulative clairvoyant reward: 53952.00
#   Cumulative agent reward:       54040.00
#   Cumulative regret: -88.00
#   Regret / T ratio:  -0.21
# --------------------------------------------------
# Trial 1, Round 420:
#   Clairvoyant action: [3, 3, 3], reward per round: 128.00
#   Agent action:       [3, 3, 3], reward this round: 146.00
#   Cumulative clairvoyant reward: 54592.00
#   Cumulative agent reward:       54680.00
#   Cumulative regret: -88.00
#   Regret / T ratio:  -0.21
# --------------------------------------------------
# My current means is
# [[20.    34.    33.    32.471 15.   ]
#  [40.    42.    49.735 40.554  6.   ]
#  [20.    48.    55.    55.795 45.   ]]
# My current avg_c is
# [[20.    17.    11.     8.118  3.   ]
#  [20.    14.    12.434  8.111  1.   ]
#  [20.    16.    11.     7.971  5.   ]]
# My current lambda is
# 2.5228477537125733
# Trial 1, Round 425:
#   Clairvoyant action: [3, 3, 3], reward per round: 128.00
#   Agent action:       [3, 3, 3], reward this round: 136.00
#   Cumulative clairvoyant reward: 55248.00
#   Cumulative agent reward:       55317.00
#   Cumulative regret: -69.00
#   Regret / T ratio:  -0.16
# --------------------------------------------------
# Trial 1, Round 430:
#   Clairvoyant action: [3, 3, 3], reward per round: 128.00
#   Agent action:       [3, 3, 3], reward this round: 165.00
#   Cumulative clairvoyant reward: 55896.00
#   Cumulative agent reward:       56014.00
#   Cumulative regret: -118.00
#   Regret / T ratio:  -0.27
# --------------------------------------------------
# My current means is
# [[20.    34.    33.    32.535 15.   ]
#  [40.    42.    49.735 40.683  6.   ]
#  [20.    48.    55.    55.733 45.   ]]
# My current avg_c is
# [[20.    17.    11.     8.134  3.   ]
#  [20.    14.    12.434  8.137  1.   ]
#  [20.    16.    11.     7.962  5.   ]]
# My current lambda is
# 2.6587295155962045
# Trial 1, Round 435:
#   Clairvoyant action: [3, 2, 3], reward per round: 136.00
#   Agent action:       [3, 3, 3], reward this round: 121.00
#   Cumulative clairvoyant reward: 56560.00
#   Cumulative agent reward:       56663.00
#   Cumulative regret: -103.00
#   Regret / T ratio:  -0.24
# --------------------------------------------------
# Trial 1, Round 440:
#   Clairvoyant action: [3, 3, 3], reward per round: 128.00
#   Agent action:       [3, 3, 3], reward this round: 131.00
#   Cumulative clairvoyant reward: 57208.00
#   Cumulative agent reward:       57266.00
#   Cumulative regret: -58.00
#   Regret / T ratio:  -0.13
# --------------------------------------------------
# My current means is
# [[20.    34.    33.    32.514 15.   ]
#  [40.    42.    49.735 40.734  6.   ]
#  [20.    48.    55.    55.626 45.   ]]
# My current avg_c is
# [[20.    17.    11.     8.128  3.   ]
#  [20.    14.    12.434  8.147  1.   ]
#  [20.    16.    11.     7.947  5.   ]]
# My current lambda is
# 2.2279228301179157
# Trial 1, Round 445:
#   Clairvoyant action: [3, 2, 3], reward per round: 136.00
#   Agent action:       [3, 3, 3], reward this round: 136.00
#   Cumulative clairvoyant reward: 57864.00
#   Cumulative agent reward:       57963.00
#   Cumulative regret: -99.00
#   Regret / T ratio:  -0.22
# --------------------------------------------------
# Trial 1, Round 450:
#   Clairvoyant action: [3, 3, 3], reward per round: 128.00
#   Agent action:       [3, 3, 3], reward this round: 106.00
#   Cumulative clairvoyant reward: 58512.00
#   Cumulative agent reward:       58550.00
#   Cumulative regret: -38.00
#   Regret / T ratio:  -0.08
# --------------------------------------------------
# My current means is
# [[20.    34.    33.    32.538 15.   ]
#  [40.    42.    49.667 40.634  6.   ]
#  [20.    48.    55.    55.666 45.   ]]
# My current avg_c is
# [[20.    17.    11.     8.135  3.   ]
#  [20.    14.    12.417  8.127  1.   ]
#  [20.    16.    11.     7.952  5.   ]]
# My current lambda is
# 1.9968606625797118
# Trial 1, Round 455:
#   Clairvoyant action: [3, 3, 3], reward per round: 128.00
#   Agent action:       [3, 2, 3], reward this round: 127.00
#   Cumulative clairvoyant reward: 59160.00
#   Cumulative agent reward:       59179.00
#   Cumulative regret: -19.00
#   Regret / T ratio:  -0.04
# --------------------------------------------------
# Trial 1, Round 460:
#   Clairvoyant action: [3, 3, 3], reward per round: 128.00
#   Agent action:       [3, 3, 3], reward this round: 94.00
#   Cumulative clairvoyant reward: 59800.00
#   Cumulative agent reward:       59796.00
#   Cumulative regret: 4.00
#   Regret / T ratio:  0.01
# --------------------------------------------------
# My current means is
# [[20.    34.    33.    32.535 15.   ]
#  [40.    42.    49.708 40.666  6.   ]
#  [20.    48.    55.    55.44  45.   ]]
# My current avg_c is
# [[20.    17.    11.     8.134  3.   ]
#  [20.    14.    12.427  8.133  1.   ]
#  [20.    16.    11.     7.92   5.   ]]
# My current lambda is
# 2.065654220319788
# Trial 1, Round 465:
#   Clairvoyant action: [3, 3, 3], reward per round: 128.00
#   Agent action:       [3, 3, 3], reward this round: 121.00
#   Cumulative clairvoyant reward: 60440.00
#   Cumulative agent reward:       60415.00
#   Cumulative regret: 25.00
#   Regret / T ratio:  0.05
# --------------------------------------------------
# Trial 1, Round 470:
#   Clairvoyant action: [3, 3, 3], reward per round: 128.00
#   Agent action:       [3, 3, 3], reward this round: 94.00
#   Cumulative clairvoyant reward: 61096.00
#   Cumulative agent reward:       61040.00
#   Cumulative regret: 56.00
#   Regret / T ratio:  0.12
# --------------------------------------------------
# My current means is
# [[20.    34.    33.    32.567 15.   ]
#  [40.    42.    49.137 40.591  6.   ]
#  [20.    48.    55.    55.376 45.   ]]
# My current avg_c is
# [[20.    17.    11.     8.142  3.   ]
#  [20.    14.    12.284  8.118  1.   ]
#  [20.    16.    11.     7.911  5.   ]]
# My current lambda is
# 2.001032760113824
# Trial 1, Round 475:
#   Clairvoyant action: [3, 3, 3], reward per round: 128.00
#   Agent action:       [3, 3, 3], reward this round: 176.00
#   Cumulative clairvoyant reward: 61752.00
#   Cumulative agent reward:       61702.00
#   Cumulative regret: 50.00
#   Regret / T ratio:  0.11
# --------------------------------------------------
# Trial 1, Round 480:
#   Clairvoyant action: [3, 3, 3], reward per round: 128.00
#   Agent action:       [3, 3, 3], reward this round: 155.00
#   Cumulative clairvoyant reward: 62408.00
#   Cumulative agent reward:       62345.00
#   Cumulative regret: 63.00
#   Regret / T ratio:  0.13
# --------------------------------------------------
# My current means is
# [[20.    34.    33.    32.571 15.   ]
#  [40.    42.    48.8   40.69   6.   ]
#  [20.    48.    55.    55.315 45.   ]]
# My current avg_c is
# [[20.    17.    11.     8.143  3.   ]
#  [20.    14.    12.2    8.138  1.   ]
#  [20.    16.    11.     7.902  5.   ]]
# My current lambda is
# 2.269771294765928
# Trial 1, Round 485:
#   Clairvoyant action: [3, 3, 3], reward per round: 128.00
#   Agent action:       [3, 2, 3], reward this round: 115.00
#   Cumulative clairvoyant reward: 63048.00
#   Cumulative agent reward:       62955.00
#   Cumulative regret: 93.00
#   Regret / T ratio:  0.19
# --------------------------------------------------
# Trial 1, Round 490:
#   Clairvoyant action: [3, 3, 3], reward per round: 128.00
#   Agent action:       [3, 3, 3], reward this round: 136.00
#   Cumulative clairvoyant reward: 63704.00
#   Cumulative agent reward:       63641.00
#   Cumulative regret: 63.00
#   Regret / T ratio:  0.13
# --------------------------------------------------
# My current means is
# [[20.    34.    33.    32.576 15.   ]
#  [40.    42.    49.01  40.664  6.   ]
#  [20.    48.    55.    55.256 45.   ]]
# My current avg_c is
# [[20.    17.    11.     8.144  3.   ]
#  [20.    14.    12.252  8.133  1.   ]
#  [20.    16.    11.     7.894  5.   ]]
# My current lambda is
# 2.405308289194688
# Trial 1, Round 495:
#   Clairvoyant action: [3, 2, 3], reward per round: 136.00
#   Agent action:       [3, 3, 3], reward this round: 132.00
#   Cumulative clairvoyant reward: 64360.00
#   Cumulative agent reward:       64283.00
#   Cumulative regret: 77.00
#   Regret / T ratio:  0.16
# --------------------------------------------------
# Trial 1, Round 500:
#   Clairvoyant action: [3, 3, 3], reward per round: 128.00
#   Agent action:       [3, 3, 3], reward this round: 141.00
#   Cumulative clairvoyant reward: 65000.00
#   Cumulative agent reward:       64923.00
#   Cumulative regret: 77.00
#   Regret / T ratio:  0.15
# --------------------------------------------------
# My current means is
# [[20.    34.    33.    32.661 15.   ]
#  [40.    42.    49.154 40.471  6.   ]
#  [20.    48.    55.    55.271 45.   ]]
# My current avg_c is
# [[20.    17.    11.     8.165  3.   ]
#  [20.    14.    12.288  8.094  1.   ]
# ...
#   Clairvoyant action: [3, 3, 3], reward per round: 128.00
#   Agent action:       [3, 2, 3], reward this round: 122.00
#   Cumulative clairvoyant reward: 1278848.00
#   Cumulative agent reward:       1276669.00
#   Cumulative regret: 2179.00
#   Regret / T ratio:  0.22
# --------------------------------------------------
# My current means is
# [[20.    34.    33.    32.076 15.   ]
#  [40.    42.    47.735 39.837  6.   ]
#  [20.    48.    55.    55.798 45.   ]]
# My current avg_c is
# [[20.    17.    11.     8.019  3.   ]
#  [20.    14.    11.934  7.967  1.   ]
#  [20.    16.    11.     7.971  5.   ]]
# My current lambda is
# 1.9312843954754189
# Trial 1, Round 9845:
#   Clairvoyant action: [3, 3, 3], reward per round: 128.00
#   Agent action:       [3, 3, 3], reward this round: 151.00
#   Cumulative clairvoyant reward: 1279488.00
#   Cumulative agent reward:       1277415.00
#   Cumulative regret: 2073.00
#   Regret / T ratio:  0.21
# --------------------------------------------------
# Trial 1, Round 9850:
#   Clairvoyant action: [3, 3, 3], reward per round: 128.00
#   Agent action:       [3, 3, 3], reward this round: 147.00
#   Cumulative clairvoyant reward: 1280128.00
#   Cumulative agent reward:       1278104.00
#   Cumulative regret: 2024.00
#   Regret / T ratio:  0.21
# --------------------------------------------------
# My current means is
# [[20.    34.    33.    32.076 15.   ]
#  [40.    42.    47.74  39.839  6.   ]
#  [20.    48.    55.    55.811 45.   ]]
# My current avg_c is
# [[20.    17.    11.     8.019  3.   ]
#  [20.    14.    11.935  7.968  1.   ]
#  [20.    16.    11.     7.973  5.   ]]
# My current lambda is
# 2.5194480687569176
# Trial 1, Round 9855:
#   Clairvoyant action: [3, 3, 3], reward per round: 128.00
#   Agent action:       [3, 3, 3], reward this round: 105.00
#   Cumulative clairvoyant reward: 1280768.00
#   Cumulative agent reward:       1278697.00
#   Cumulative regret: 2071.00
#   Regret / T ratio:  0.21
# --------------------------------------------------
# Trial 1, Round 9860:
#   Clairvoyant action: [3, 3, 3], reward per round: 128.00
#   Agent action:       [3, 2, 3], reward this round: 119.00
#   Cumulative clairvoyant reward: 1281408.00
#   Cumulative agent reward:       1279271.00
#   Cumulative regret: 2137.00
#   Regret / T ratio:  0.22
# --------------------------------------------------
# My current means is
# [[20.    34.    33.    32.073 15.   ]
#  [40.    42.    47.741 39.837  6.   ]
#  [20.    48.    55.    55.8   45.   ]]
# My current avg_c is
# [[20.    17.    11.     8.018  3.   ]
#  [20.    14.    11.935  7.967  1.   ]
#  [20.    16.    11.     7.971  5.   ]]
# My current lambda is
# 1.9133881702836688
# Trial 1, Round 9865:
#   Clairvoyant action: [3, 3, 3], reward per round: 128.00
#   Agent action:       [3, 3, 3], reward this round: 153.00
#   Cumulative clairvoyant reward: 1282072.00
#   Cumulative agent reward:       1279991.00
#   Cumulative regret: 2081.00
#   Regret / T ratio:  0.21
# --------------------------------------------------
# Trial 1, Round 9870:
#   Clairvoyant action: [3, 3, 3], reward per round: 128.00
#   Agent action:       [3, 3, 3], reward this round: 142.00
#   Cumulative clairvoyant reward: 1282728.00
#   Cumulative agent reward:       1280698.00
#   Cumulative regret: 2030.00
#   Regret / T ratio:  0.21
# --------------------------------------------------
# My current means is
# [[20.    34.    33.    32.079 15.   ]
#  [40.    42.    47.745 39.844  6.   ]
#  [20.    48.    55.    55.803 45.   ]]
# My current avg_c is
# [[20.    17.    11.     8.02   3.   ]
#  [20.    14.    11.936  7.969  1.   ]
#  [20.    16.    11.     7.972  5.   ]]
# My current lambda is
# 2.7391277905998184
# Trial 1, Round 9875:
#   Clairvoyant action: [3, 3, 3], reward per round: 128.00
#   Agent action:       [3, 3, 3], reward this round: 141.00
#   Cumulative clairvoyant reward: 1283368.00
#   Cumulative agent reward:       1281426.00
#   Cumulative regret: 1942.00
#   Regret / T ratio:  0.20
# --------------------------------------------------
# Trial 1, Round 9880:
#   Clairvoyant action: [3, 3, 3], reward per round: 128.00
#   Agent action:       [3, 3, 3], reward this round: 171.00
#   Cumulative clairvoyant reward: 1284016.00
#   Cumulative agent reward:       1282063.00
#   Cumulative regret: 1953.00
#   Regret / T ratio:  0.20
# --------------------------------------------------
# My current means is
# [[20.    34.    33.    32.079 15.   ]
#  [40.    42.    47.745 39.838  6.   ]
#  [20.    48.    55.    55.816 45.   ]]
# My current avg_c is
# [[20.    17.    11.     8.02   3.   ]
#  [20.    14.    11.936  7.968  1.   ]
#  [20.    16.    11.     7.974  5.   ]]
# My current lambda is
# 2.790901598496306
# Trial 1, Round 9885:
#   Clairvoyant action: [3, 3, 3], reward per round: 128.00
#   Agent action:       [3, 3, 3], reward this round: 88.00
#   Cumulative clairvoyant reward: 1284672.00
#   Cumulative agent reward:       1282626.00
#   Cumulative regret: 2046.00
#   Regret / T ratio:  0.21
# --------------------------------------------------
# Trial 1, Round 9890:
#   Clairvoyant action: [3, 3, 3], reward per round: 128.00
#   Agent action:       [3, 3, 3], reward this round: 114.00
#   Cumulative clairvoyant reward: 1285312.00
#   Cumulative agent reward:       1283267.00
#   Cumulative regret: 2045.00
#   Regret / T ratio:  0.21
# --------------------------------------------------
# My current means is
# [[20.    34.    33.    32.075 15.   ]
#  [40.    42.    47.745 39.835  6.   ]
#  [20.    48.    55.    55.815 45.   ]]
# My current avg_c is
# [[20.    17.    11.     8.019  3.   ]
#  [20.    14.    11.936  7.967  1.   ]
#  [20.    16.    11.     7.974  5.   ]]
# My current lambda is
# 1.8993381928776025
# Trial 1, Round 9895:
#   Clairvoyant action: [3, 3, 3], reward per round: 128.00
#   Agent action:       [3, 3, 3], reward this round: 85.00
#   Cumulative clairvoyant reward: 1285952.00
#   Cumulative agent reward:       1283879.00
#   Cumulative regret: 2073.00
#   Regret / T ratio:  0.21
# --------------------------------------------------
# Trial 1, Round 9900:
#   Clairvoyant action: [3, 3, 3], reward per round: 128.00
#   Agent action:       [3, 3, 3], reward this round: 120.00
#   Cumulative clairvoyant reward: 1286592.00
#   Cumulative agent reward:       1284569.00
#   Cumulative regret: 2023.00
#   Regret / T ratio:  0.20
# --------------------------------------------------
# My current means is
# [[20.    34.    33.    32.073 15.   ]
#  [40.    42.    47.75  39.833  6.   ]
#  [20.    48.    55.    55.815 45.   ]]
# My current avg_c is
# [[20.    17.    11.     8.018  3.   ]
#  [20.    14.    11.938  7.967  1.   ]
#  [20.    16.    11.     7.974  5.   ]]
# My current lambda is
# 2.1856138739140247
# Trial 1, Round 9905:
#   Clairvoyant action: [3, 3, 3], reward per round: 128.00
#   Agent action:       [3, 3, 3], reward this round: 127.00
#   Cumulative clairvoyant reward: 1287248.00
#   Cumulative agent reward:       1285206.00
#   Cumulative regret: 2042.00
#   Regret / T ratio:  0.21
# --------------------------------------------------
# Trial 1, Round 9910:
#   Clairvoyant action: [3, 3, 3], reward per round: 128.00
#   Agent action:       [3, 2, 3], reward this round: 124.00
#   Cumulative clairvoyant reward: 1287896.00
#   Cumulative agent reward:       1285808.00
#   Cumulative regret: 2088.00
#   Regret / T ratio:  0.21
# --------------------------------------------------
# My current means is
# [[20.    34.    33.    32.069 15.   ]
#  [40.    42.    47.748 39.834  6.   ]
#  [20.    48.    55.    55.811 45.   ]]
# My current avg_c is
# [[20.    17.    11.     8.017  3.   ]
#  [20.    14.    11.937  7.967  1.   ]
#  [20.    16.    11.     7.973  5.   ]]
# My current lambda is
# 1.8639329074544835
# Trial 1, Round 9915:
#   Clairvoyant action: [3, 3, 3], reward per round: 128.00
#   Agent action:       [3, 3, 3], reward this round: 141.00
#   Cumulative clairvoyant reward: 1288536.00
#   Cumulative agent reward:       1286514.00
#   Cumulative regret: 2022.00
#   Regret / T ratio:  0.20
# --------------------------------------------------
# Trial 1, Round 9920:
#   Clairvoyant action: [3, 3, 3], reward per round: 128.00
#   Agent action:       [3, 3, 3], reward this round: 145.00
#   Cumulative clairvoyant reward: 1289184.00
#   Cumulative agent reward:       1287225.00
#   Cumulative regret: 1959.00
#   Regret / T ratio:  0.20
# --------------------------------------------------
# My current means is
# [[20.    34.    33.    32.069 15.   ]
#  [40.    42.    47.742 39.832  6.   ]
#  [20.    48.    55.    55.826 45.   ]]
# My current avg_c is
# [[20.    17.    11.     8.017  3.   ]
#  [20.    14.    11.936  7.966  1.   ]
#  [20.    16.    11.     7.975  5.   ]]
# My current lambda is
# 2.475482084180123
# Trial 1, Round 9925:
#   Clairvoyant action: [3, 2, 3], reward per round: 136.00
#   Agent action:       [3, 3, 3], reward this round: 134.00
#   Cumulative clairvoyant reward: 1289832.00
#   Cumulative agent reward:       1287868.00
#   Cumulative regret: 1964.00
#   Regret / T ratio:  0.20
# --------------------------------------------------
# Trial 1, Round 9930:
#   Clairvoyant action: [3, 3, 3], reward per round: 128.00
#   Agent action:       [3, 3, 3], reward this round: 161.00
#   Cumulative clairvoyant reward: 1290488.00
#   Cumulative agent reward:       1288504.00
#   Cumulative regret: 1984.00
#   Regret / T ratio:  0.20
# --------------------------------------------------
# My current means is
# [[20.    34.    33.    32.069 15.   ]
#  [40.    42.    47.742 39.837  6.   ]
#  [20.    48.    55.    55.822 45.   ]]
# My current avg_c is
# [[20.    17.    11.     8.017  3.   ]
#  [20.    14.    11.936  7.967  1.   ]
#  [20.    16.    11.     7.975  5.   ]]
# My current lambda is
# 2.239678434287409
# Trial 1, Round 9935:
#   Clairvoyant action: [3, 3, 3], reward per round: 128.00
#   Agent action:       [3, 3, 3], reward this round: 128.00
#   Cumulative clairvoyant reward: 1291152.00
#   Cumulative agent reward:       1289139.00
#   Cumulative regret: 2013.00
#   Regret / T ratio:  0.20
# --------------------------------------------------
# Trial 1, Round 9940:
#   Clairvoyant action: [3, 3, 3], reward per round: 128.00
#   Agent action:       [3, 3, 3], reward this round: 143.00
#   Cumulative clairvoyant reward: 1291800.00
#   Cumulative agent reward:       1289794.00
#   Cumulative regret: 2006.00
#   Regret / T ratio:  0.20
# --------------------------------------------------
# My current means is
# [[20.    34.    33.    32.068 15.   ]
#  [40.    42.    47.736 39.835  6.   ]
#  [20.    48.    55.    55.824 45.   ]]
# My current avg_c is
# [[20.    17.    11.     8.017  3.   ]
#  [20.    14.    11.934  7.967  1.   ]
#  [20.    16.    11.     7.975  5.   ]]
# My current lambda is
# 2.1117552584701427
# Trial 1, Round 9945:
#   Clairvoyant action: [3, 3, 3], reward per round: 128.00
#   Agent action:       [3, 3, 3], reward this round: 122.00
#   Cumulative clairvoyant reward: 1292448.00
#   Cumulative agent reward:       1290460.00
#   Cumulative regret: 1988.00
#   Regret / T ratio:  0.20
# --------------------------------------------------
# Trial 1, Round 9950:
#   Clairvoyant action: [3, 3, 3], reward per round: 128.00
#   Agent action:       [3, 3, 3], reward this round: 152.00
#   Cumulative clairvoyant reward: 1293088.00
#   Cumulative agent reward:       1291186.00
#   Cumulative regret: 1902.00
#   Regret / T ratio:  0.19
# --------------------------------------------------
# My current means is
# [[20.    34.    33.    32.068 15.   ]
#  [40.    42.    47.736 39.835  6.   ]
#  [20.    48.    55.    55.836 45.   ]]
# My current avg_c is
# [[20.    17.    11.     8.017  3.   ]
#  [20.    14.    11.934  7.967  1.   ]
#  [20.    16.    11.     7.977  5.   ]]
# My current lambda is
# 2.312338880052912
# Trial 1, Round 9955:
#   Clairvoyant action: [3, 3, 3], reward per round: 128.00
#   Agent action:       [3, 3, 3], reward this round: 161.00
#   Cumulative clairvoyant reward: 1293728.00
#   Cumulative agent reward:       1291888.00
#   Cumulative regret: 1840.00
#   Regret / T ratio:  0.18
# --------------------------------------------------
# Trial 1, Round 9960:
#   Clairvoyant action: [3, 2, 3], reward per round: 136.00
#   Agent action:       [3, 3, 3], reward this round: 99.00
#   Cumulative clairvoyant reward: 1294376.00
#   Cumulative agent reward:       1292531.00
#   Cumulative regret: 1845.00
#   Regret / T ratio:  0.19
# --------------------------------------------------
# My current means is
# [[20.    34.    33.    32.068 15.   ]
#  [40.    42.    47.736 39.833  6.   ]
#  [20.    48.    55.    55.845 45.   ]]
# My current avg_c is
# [[20.    17.    11.     8.017  3.   ]
#  [20.    14.    11.934  7.967  1.   ]
#  [20.    16.    11.     7.978  5.   ]]
# My current lambda is
# 2.285650050876027
# Trial 1, Round 9965:
#   Clairvoyant action: [3, 3, 3], reward per round: 128.00
#   Agent action:       [3, 3, 3], reward this round: 150.00
#   Cumulative clairvoyant reward: 1295024.00
#   Cumulative agent reward:       1293177.00
#   Cumulative regret: 1847.00
#   Regret / T ratio:  0.19
# --------------------------------------------------
# Trial 1, Round 9970:
#   Clairvoyant action: [3, 3, 3], reward per round: 128.00
#   Agent action:       [3, 2, 3], reward this round: 133.00
#   Cumulative clairvoyant reward: 1295664.00
#   Cumulative agent reward:       1293785.00
#   Cumulative regret: 1879.00
#   Regret / T ratio:  0.19
# --------------------------------------------------
# My current means is
# [[20.    34.    33.    32.068 15.   ]
#  [40.    42.    47.74  39.831  6.   ]
#  [20.    48.    55.    55.84  45.   ]]
# My current avg_c is
# [[20.    17.    11.     8.017  3.   ]
#  [20.    14.    11.935  7.966  1.   ]
#  [20.    16.    11.     7.977  5.   ]]
# My current lambda is
# 2.0777309493245846
# Trial 1, Round 9975:
#   Clairvoyant action: [3, 3, 3], reward per round: 128.00
#   Agent action:       [3, 3, 3], reward this round: 142.00
#   Cumulative clairvoyant reward: 1296312.00
#   Cumulative agent reward:       1294423.00
#   Cumulative regret: 1889.00
#   Regret / T ratio:  0.19
# --------------------------------------------------
# Trial 1, Round 9980:
#   Clairvoyant action: [3, 3, 3], reward per round: 128.00
#   Agent action:       [3, 3, 3], reward this round: 163.00
#   Cumulative clairvoyant reward: 1296952.00
#   Cumulative agent reward:       1295143.00
#   Cumulative regret: 1809.00
#   Regret / T ratio:  0.18
# --------------------------------------------------
# My current means is
# [[20.    34.    33.    32.074 15.   ]
#  [40.    42.    47.738 39.829  6.   ]
#  [20.    48.    55.    55.843 45.   ]]
# My current avg_c is
# [[20.    17.    11.     8.019  3.   ]
#  [20.    14.    11.935  7.966  1.   ]
#  [20.    16.    11.     7.978  5.   ]]
# My current lambda is
# 2.485117552448819
# Trial 1, Round 9985:
#   Clairvoyant action: [3, 3, 3], reward per round: 128.00
#   Agent action:       [3, 3, 3], reward this round: 120.00
#   Cumulative clairvoyant reward: 1297600.00
#   Cumulative agent reward:       1295839.00
#   Cumulative regret: 1761.00
#   Regret / T ratio:  0.18
# --------------------------------------------------
# Trial 1, Round 9990:
#   Clairvoyant action: [3, 2, 3], reward per round: 136.00
#   Agent action:       [3, 3, 3], reward this round: 102.00
#   Cumulative clairvoyant reward: 1298256.00
#   Cumulative agent reward:       1296405.00
#   Cumulative regret: 1851.00
#   Regret / T ratio:  0.19
# --------------------------------------------------
# My current means is
# [[20.    34.    33.    32.075 15.   ]
#  [40.    42.    47.738 39.824  6.   ]
#  [20.    48.    55.    55.844 45.   ]]
# My current avg_c is
# [[20.    17.    11.     8.019  3.   ]
#  [20.    14.    11.935  7.965  1.   ]
#  [20.    16.    11.     7.978  5.   ]]
# My current lambda is
# 2.1822108787991112
# Trial 1, Round 9995:
#   Clairvoyant action: [3, 2, 3], reward per round: 136.00
#   Agent action:       [3, 2, 3], reward this round: 118.00
#   Cumulative clairvoyant reward: 1298904.00
#   Cumulative agent reward:       1297037.00
#   Cumulative regret: 1867.00
#   Regret / T ratio:  0.19
# --------------------------------------------------
# Trial 1, Round 10000:
#   Clairvoyant action: [3, 2, 3], reward per round: 136.00
#   Agent action:       [3, 3, 3], reward this round: 118.00
#   Cumulative clairvoyant reward: 1299568.00
#   Cumulative agent reward:       1297710.00
#   Cumulative regret: 1858.00
#   Regret / T ratio:  0.19
# --------------------------------------------------
#
# --- Final regret/T ratio per trial ---
# Trial 1: regret/T = 0.19
# Average final regret/T over 1 trials: 0.19
