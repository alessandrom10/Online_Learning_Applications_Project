# %% [markdown]
# #Multiple products and stochastic environment

# %% [markdown]
# Parameters :
#
# *   T rounds
# *   N number of types of products
# *   P set of possible prices
# *   B prduction capacity

# %%
import numpy as np
import matplotlib.pyplot as plt
import networkx as nx # we will use it mostly for visualization
from scipy.optimize import linear_sum_assignment
from scipy.optimize import milp
from scipy import optimize
from scipy.sparse.csgraph import shortest_path

# %%
num_products = 3
num_prices = 5
n_customers = 20
T = 10000
I = 250000
n_trials = 15

# List of products
# products = ["Laptop", "Mouse", "Keyboard", "Smartphone", "Headphones"]
# costs = [800.00, 10.50, 20.00, 200.00, 50.00]

products = ["Pencil", "Rubber", "Notebook"]
costs = [0.50, 0.10, 1.00]

prices = [ 0.10, 0.70, 1.20, 2.00, 5.00]

# profit matrix
W = np.zeros((num_products, num_prices))
for i, cost in enumerate(costs):
    for j, price in enumerate(prices):
        profit = price - cost
        if W[i, j] < profit:
           W[i, j] = profit if profit > 0 else -999

# %%
alpha = {
    "Pencil": 3.0,      # r ≈ 1
    "Rubber":  8.0,      # r ≈ 0.4
    "Notebook": 3.0,    # r ≈ 2
    # "Smartphone": 4.2,     # r ≈ 440
    # "Headphones": 5.0   # r ≈ 150
}

# Build reservation prices r_i
r = np.array([alpha[name] * c for name, c in zip(products, costs)], dtype=float)

p_max = 0.95  # cap max conversion

def conversion_probability(i, price):
    c_i, r_i = costs[i], r[i]
    # Handle degenerate case if r_i <= c_i (force a tiny spread)
    if r_i <= c_i:
        r_i = c_i + 1e-6
    if price <= c_i:
        return 0.95
    if price >= r_i:
        return 0.0
    # Linear decay from c_i (p_max) to r_i (0)
    return p_max * (r_i - price) / (r_i - c_i)
X  = np.zeros((num_products, num_prices))
for i in range(num_products):
    for j in range(num_prices):
        X[i, j] = conversion_probability(i, prices[j]) * n_customers

print(X)
# Out:
# [[19.         15.2         5.7         0.          0.        ]
#  [19.          2.71428571  0.          0.          0.        ]
#  [19.         19.         17.1         9.5         0.        ]]

# %%
import networkx as nx
import numpy as np
import matplotlib.pyplot as plt

def plot_weighted_matching_custom(matching, W, prd, prc, with_zeros=False):
    """
    matching : list of (i,j) pairs, indices of matched product i to price j
    W        : weight matrix (products x prices)
    prd      : list of product names (len = W.shape[0])
    prc      : list of price names/labels (len = W.shape[1])
    with_zeros : if True, show edges with weight 0 too
    """
    B = nx.Graph()

    # add product nodes (left side of bipartite)
    B.add_nodes_from(prd, bipartite=0)

    # add price nodes (right side of bipartite)
    B.add_nodes_from(prc, bipartite=1)

    # add edges with weights
    for i, j in matching:
        if with_zeros or W[i, j] > 0:
            B.add_edge(prd[i], prc[j])

    # bipartite layout: fix product side
    pos = nx.drawing.layout.bipartite_layout(B, prd)

    # draw graph
    nx.draw_networkx(B, pos=pos, width=2, with_labels=True, node_size=2000, node_color="lightblue")

    # draw edge labels with weights
    edge_labels = nx.get_edge_attributes(B, "weight")
    nx.draw_networkx_edge_labels(B, pos, edge_labels=edge_labels)

    plt.show()

# %%
def precomputed_realizations(products, prices, T, W):
  x = np.zeros((T,W.shape[0],W.shape[1]))
  for i, product in enumerate(products):
          for j, price in enumerate(prices):
              p = conversion_probability(i, price)  # compute conversion probability for this product-price
              x[:, i, j] = np.random.binomial(n=n_customers, p=p, size=T)

  return x

# %%
realization = precomputed_realizations(products, prices, T, W)

# %%
class BernoulliMatchingEnv:
    def __init__(self, W, T, costs, prices, n_customers, I, realization):
        self.W = W
        self.I = I
        self.n_customers = n_customers
        self.costs = np.array(costs)
        self.price_values = np.array(prices)
        # we can generate the realization in advance
        self.realizations = realization
        self.t = 0

    def print_Real(self):
        print(self.realizations)

    def round(self, matching):
        """
        matching: list of (product_index, price_index) tuples
        Reward is computed as profit = (price - cost[product]) * demand
        Demand is sampled from Bernoulli conversion probabilities.
        If price == -1, demand and reward are set to 0.
        """
        products, prices = list(zip(*matching))
        products = np.array(products)
        prices   = np.array(prices)

        # Initialize demand and reward as zeros
        d_t = np.zeros(len(products), dtype=int)
        r_t = np.zeros(len(products), dtype=float)

        # Mask for valid prices
        valid_mask = prices != -1

        if np.any(valid_mask):
            # Conversion probabilities for valid entries
            d_valid = self.realizations[self.t][products[valid_mask], prices[valid_mask]]

            # Compute profits: (price_value - cost) * demand
            r_valid = np.maximum(
                (self.price_values[prices[valid_mask]] - self.costs[products[valid_mask]]) * d_valid,
                0
            )

            # Assign back to full arrays
            d_t[valid_mask] = d_valid
            r_t[valid_mask] = r_valid

        self.t += 1
        return d_t, r_t

# %%
from scipy import optimize


class CombinatorialUCB:
    def __init__(self, N, P, B, T):
        """
        N: number of products
        P: number of prices
        B: shared capacity (not used right now)
        """
        self.N = N
        self.P = P
        self.B = B
        self.remaining_inventory = B
        self.T = T
        self.counts = np.zeros((N, P))  # times each arm is chosen
        self.means = np.zeros((N, P))   # estimated mean rewards
        self.avg_c = np.zeros((N, P))
        self.t = 0

    def pull_arm(self):
        prices = []

        # If inventory exhausted, sell nothing
        if self.remaining_inventory < 1:
            prices = [-1] * self.N
            return prices

        if self.t < self.P:
            prices = [self.t % self.P] * self.N
            return prices

        f_ucbs = self.means + np.sqrt(2*np.log(self.t + 1)/(self.counts + 1e-6))
        c_lcbs = self.avg_c - np.sqrt(2*np.log(self.t + 1)/(self.counts + 1e-6))

        rho = self.remaining_inventory / max(1, self.T - self.t)

        # compute LP to get probabilities over product/price pairs
        gamma = self.compute_opt(f_ucbs, c_lcbs, rho)

        for i in range(self.N):
            probs = np.clip(gamma[i], 0, None)
            probs /= probs.sum()

            price_idx = np.random.choice(len(probs), p=probs)

            # If the sampled index is 0, treat it as "do not sell"
            if price_idx == 0:
                prices.append(-1)
            else:
                prices.append(price_idx - 1)  # shift back to match original price indices

        return prices


    def compute_opt(self, f_ucbs, c_lcbs, rho):
        """
        Args:
        f_ucbs: (N x P) upper confidence bounds on expected rewards
        c_lcbs: (N x P) lower confidence bounds on expected consumptions
        rho: per-round budget (remaining_inventory / remaining_time)

        Returns:
            gamma: (N x (P+1)) array of probabilities over price choices
        """
        N, P = self.N, self.P

        # Add dummy price (0 reward, 0 cost) as first column (it's equivalent to "do not sell")
        f_ucbs = np.hstack([np.zeros((N, 1)), f_ucbs])
        c_lcbs = np.hstack([np.zeros((N, 1)), c_lcbs])

        # Objective: maximize expected reward
        c_obj = -f_ucbs.flatten()

        # Bounds: gamma_ij >= 0
        bounds = (0, 1)

        # Equality constraints: sum of each row = 1
        A_eq = np.zeros((N, N * (P + 1)))
        b_eq = np.ones(N)
        for i in range(N):
            for j in range(P + 1):
                A_eq[i, i * (P + 1) + j] = 1

        # Inequality constraint: expected cost <= rho
        A_ub = [c_lcbs.flatten()]
        b_ub = [rho]

        res = optimize.linprog(c=c_obj, A_ub=A_ub, b_ub=b_ub, A_eq=A_eq, b_eq=b_eq, bounds=bounds)

        if res.success:
            gamma = res.x.reshape(N, P + 1)
        else:
            gamma = np.zeros((N, P + 1))

        return gamma



    def update(self, prices, demand, rewards):
        """
        prices: list of chosen price indices per product (-1 if product not sold)
        demand: list of units sold per product
        rewards: observed per-product reward
        """
        self.t += 1

        for i in range(self.N):
            p = prices[i]
            if p == -1:
                continue  # product not sold, skip

            units_sold = demand[i]

            # Update inventory
            self.remaining_inventory -= units_sold
            if self.remaining_inventory < 0:
                self.remaining_inventory = 0  # inventory can't go negative

            # Update estimated mean reward for this product/price pair
            self.counts[i, p] += 1
            n = self.counts[i, p]
            self.means[i, p] += (rewards[i] - self.means[i, p]) / n

            self.avg_c[i, p] += (units_sold - self.avg_c[i, p]) / n

# %%
import numpy as np

def realized_clairvoyant(realizations, prices, costs, n_customers, B, T):
    """
    realizations : array [T, N, P] with conversion probabilities
    prices       : list of price values (len = P)
    costs        : list of costs (len = N)
    n_customers  : customers per round
    B            : total inventory
    T            : horizon
    Returns:
        total_reward : total profit over horizon
        reward_per_rounds : list of total profit per round
    """
    N, P = len(costs), len(prices)
    total_reward, B_left = 0, B
    reward_per_rounds = []

    for t in range(T):
        if B_left <= 0:
            reward_per_rounds.append(0)
            continue
        else :
            round_reward = 0

            # for each product, pick the best price
            for i in range(N):
                best_j = None
                best_profit = -np.inf
                for j in range(P):
                    demand = realizations[t][i, j]
                    unit_profit = prices[j] - costs[i]
                    profit = unit_profit * demand
                    #print(f"product"+ str(i)+ "with price :"+ str(prices[j])+ "with demand :"+ str(demand)+ "profiti "+str(profit))
                    if profit > best_profit:
                        best_profit = profit
                        best_j = j

                if best_profit > 0:
                    #print(f"product"+ str(i)+ "with price :"+ str(best_j)+ "with profit :"+ str(best_profit))
                    round_reward += best_profit
                    # B_left -= realizations[t][i, best_j]  # each product "consumes" as much inventory units as the demand

                    # if B_left <= 0:
                    #     break  # stop if inventory exhausted

            reward_per_rounds.append(round_reward)
            total_reward += round_reward

    return total_reward, reward_per_rounds

# %%
clairvoyant_total_reward, clay_per_round = realized_clairvoyant(realization, prices, costs, n_customers, I, T)
print(clairvoyant_total_reward)
# Out:
# 154060.99999999965

# %%
# deterministic clairvoyant
best_pairs = np.zeros((num_products, 2))

for i in range(num_products):
    best_reward = 0
    for j in range(num_prices):
        expected = W[i, j] * conversion_probability(i, prices[j]) * n_customers

        if expected > best_reward:
            # found a strictly better reward → reset list
            best_reward = expected
            best_pairs[i, 0] = i
            best_pairs[i, 1] = j

clairvoyant_matching = list(best_pairs)

# %%
last = []
l_agent = 0
overtrials_agentreward = 0
overtrials_clay = 0
overtrials_regret = 0
overtrials_avgregret = 0
np.random.seed(32)
W = np.random.rand(num_products, num_prices) # Remove random W initialization here

avg_regret_ratio_per_round = np.zeros(T)
avg_regret = np.zeros(T)
avg_inventory_per_trial = np.zeros(T)

for i in range(n_trials):
    realization = precomputed_realizations(products, prices, T, W) # Remove random W initialization here
    clairvoyant_total_reward, clay_per_round = realized_clairvoyant(realization, prices, costs, n_customers, I, T)


    env = BernoulliMatchingEnv(W, T, costs, prices, n_customers, I, realization)
    agent = CombinatorialUCB(
        N=len(products),
        P=len(prices),
        B=I,                  # shared capacity
        T=T
    )

    agent_rewards = np.array([])
    agent_superarms = []

    history_agent_rewards = []
    regret_ratio_per_round = []
    regret_per_trial = []
    cumulative_regret = 0
    rem_inventory = []

    for t in range(T):
        prices_agent = agent.pull_arm()

        # Construct the matching list in the correct format (product_index, price_index)
        matching_for_env = []
        for product_idx, price_idx in enumerate(prices_agent):
            matching_for_env.append((product_idx, price_idx))

        demand_agent, rewards_agent = env.round(matching_for_env)
        agent.update(prices_agent, demand_agent, rewards_agent)

        history_agent_rewards.append(rewards_agent.sum())  # Sum the rewards for the round
        rem_inventory.append(agent.remaining_inventory)

        diff = clay_per_round[t] - rewards_agent.sum()
        cumulative_regret += diff

        regret_ratio_per_round.append(
            (cumulative_regret / (t + 1))
        )
        regret_per_trial.append(cumulative_regret)

        if i == 0 and t % 20 == 0 :
          print(f"Trail {i} Round {t+1:2d}")
          print(f"  Agent prices:  {prices_agent}")
          print(f"  Demand:        {demand_agent}")
          print(f"  Remaining B:   {agent.remaining_inventory}")
          print(f"  Agent Rewards:       {rewards_agent}")
          print(f"  Clay Rewards:       {clay_per_round[t]}")
          print(f"  TOT Agent Rewards:       {rewards_agent.sum()}")

        if t == 0 or rewards_agent.sum() > l_agent:
            last = prices_agent
            l_agent = rewards_agent.sum()

    avg_regret_ratio_per_round += np.array(regret_ratio_per_round) # Accumulate here
    avg_regret += np.array(regret_per_trial)
    # Final comparison
    total_agent_reward = sum(history_agent_rewards)
    total_regret = clairvoyant_total_reward - total_agent_reward
    avg_ratio = np.sum(regret_ratio_per_round) / len(regret_ratio_per_round)

    if i == 0 :
        avg_inventory_per_trial = np.array(rem_inventory)
    else :
        for j in range(T):
            avg_inventory_per_trial[j] = avg_inventory_per_trial[j] * j + rem_inventory[j]
            avg_inventory_per_trial[j] = avg_inventory_per_trial[j] / (j + 1)


    print(f"=== Final Results Trail {i} ===")
    print(f"Total agent reward:       {total_agent_reward:.2f}")
    print(f"Deterministic clairvoyant reward: {clairvoyant_total_reward:.2f}")
    print(f"Total regret:             {total_regret:.2f}")
    print(f"Average regret ratio:     {avg_ratio:.3f}")

    overtrials_clay += clairvoyant_total_reward
    overtrials_agentreward += total_agent_reward
    overtrials_regret += total_regret
    overtrials_avgregret += avg_ratio

avg_regret_ratio_per_round /= n_trials # Divide by the number of trials here
avg_regret /= n_trials
# Out:
# Trail 0 Round  1
#   Agent prices:  [0, 0, 0]
#   Demand:        [19 18 19]
#   Remaining B:   249944
#   Agent Rewards:       [0. 0. 0.]
#   Clay Rewards:       10.7
#   TOT Agent Rewards:       0.0
# Trail 0 Round 21
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 9  0 11]
#   Remaining B:   249562
#   Agent Rewards:       [ 6.3  0.  11. ]
#   Clay Rewards:       17.3
#   TOT Agent Rewards:       17.3
# Trail 0 Round 41
#   Agent prices:  [2, 2, 3]
#   Demand:        [ 3  0 12]
#   Remaining B:   249207
#   Agent Rewards:       [ 2.1  0.  12. ]
#   Clay Rewards:       15.799999999999999
#   TOT Agent Rewards:       14.1
# Trail 0 Round 61
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 6  3 11]
#   Remaining B:   248811
#   Agent Rewards:       [ 4.2  1.8 11. ]
#   Clay Rewards:       17.0
#   TOT Agent Rewards:       17.0
# Trail 0 Round 81
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 8  1 11]
#   Remaining B:   248422
#   Agent Rewards:       [ 5.6  0.6 11. ]
#   Clay Rewards:       17.2
#   TOT Agent Rewards:       17.2
# Trail 0 Round 101
#   Agent prices:  [2, 1, 3]
#   Demand:        [2 2 9]
#   Remaining B:   248061
#   Agent Rewards:       [1.4 1.2 9. ]
#   Clay Rewards:       13.0
#   TOT Agent Rewards:       11.6
# Trail 0 Round 121
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 9  2 13]
#   Remaining B:   247700
#   Agent Rewards:       [ 6.3  1.2 13. ]
#   Clay Rewards:       20.5
#   TOT Agent Rewards:       20.5
# Trail 0 Round 141
#   Agent prices:  [2, 1, 3]
#   Demand:        [5 0 6]
#   Remaining B:   247323
#   Agent Rewards:       [3.5 0.  6. ]
#   Clay Rewards:       9.5
#   TOT Agent Rewards:       9.5
# Trail 0 Round 161
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 8  2 14]
#   Remaining B:   246946
#   Agent Rewards:       [ 5.6  1.2 14. ]
#   Clay Rewards:       20.8
#   TOT Agent Rewards:       20.8
# Trail 0 Round 181
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 6  1 13]
#   Remaining B:   246596
#   Agent Rewards:       [ 4.2  0.6 13. ]
#   Clay Rewards:       17.799999999999997
#   TOT Agent Rewards:       17.799999999999997
# Trail 0 Round 201
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 9  4 12]
#   Remaining B:   246219
#   Agent Rewards:       [ 6.3  2.4 12. ]
#   Clay Rewards:       20.7
#   TOT Agent Rewards:       20.7
# Trail 0 Round 221
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 9  5 12]
#   Remaining B:   245859
#   Agent Rewards:       [ 6.3  3.  12. ]
#   Clay Rewards:       21.3
#   TOT Agent Rewards:       21.3
# Trail 0 Round 241
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 5  3 10]
#   Remaining B:   245497
#   Agent Rewards:       [ 3.5  1.8 10. ]
#   Clay Rewards:       15.3
#   TOT Agent Rewards:       15.3
# Trail 0 Round 261
#   Agent prices:  [2, 1, 3]
#   Demand:        [10  3 11]
#   Remaining B:   245131
#   Agent Rewards:       [ 7.   1.8 11. ]
#   Clay Rewards:       19.8
#   TOT Agent Rewards:       19.8
# Trail 0 Round 281
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 8  4 12]
#   Remaining B:   244765
#   Agent Rewards:       [ 5.6  2.4 12. ]
#   Clay Rewards:       20.0
#   TOT Agent Rewards:       20.0
# Trail 0 Round 301
#   Agent prices:  [2, 1, 3]
#   Demand:        [7 0 9]
#   Remaining B:   244418
#   Agent Rewards:       [4.9 0.  9. ]
#   Clay Rewards:       13.899999999999999
#   TOT Agent Rewards:       13.899999999999999
# Trail 0 Round 321
#   Agent prices:  [2, 1, 3]
#   Demand:        [5 2 9]
#   Remaining B:   244053
#   Agent Rewards:       [3.5 1.2 9. ]
#   Clay Rewards:       13.7
#   TOT Agent Rewards:       13.7
# Trail 0 Round 341
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 8  2 12]
#   Remaining B:   243690
#   Agent Rewards:       [ 5.6  1.2 12. ]
#   Clay Rewards:       18.8
#   TOT Agent Rewards:       18.8
# Trail 0 Round 361
#   Agent prices:  [2, 1, 3]
#   Demand:        [5 2 6]
#   Remaining B:   243318
#   Agent Rewards:       [3.5 1.2 6. ]
#   Clay Rewards:       10.7
#   TOT Agent Rewards:       10.7
# Trail 0 Round 381
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 3  3 10]
#   Remaining B:   242935
#   Agent Rewards:       [ 2.1  1.8 10. ]
#   Clay Rewards:       15.2
#   TOT Agent Rewards:       13.899999999999999
# Trail 0 Round 401
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 3  3 11]
#   Remaining B:   242578
#   Agent Rewards:       [ 2.1  1.8 11. ]
#   Clay Rewards:       15.2
#   TOT Agent Rewards:       14.899999999999999
# Trail 0 Round 421
#   Agent prices:  [2, 1, 3]
#   Demand:        [3 7 7]
#   Remaining B:   242232
#   Agent Rewards:       [2.1 4.2 7. ]
#   Clay Rewards:       14.399999999999999
#   TOT Agent Rewards:       13.3
# Trail 0 Round 441
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 7  3 13]
#   Remaining B:   241868
#   Agent Rewards:       [ 4.9  1.8 13. ]
#   Clay Rewards:       19.7
#   TOT Agent Rewards:       19.7
# Trail 0 Round 461
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 7  1 10]
#   Remaining B:   241496
#   Agent Rewards:       [ 4.9  0.6 10. ]
#   Clay Rewards:       15.5
#   TOT Agent Rewards:       15.5
# Trail 0 Round 481
#   Agent prices:  [2, 1, 3]
#   Demand:        [10  2  8]
#   Remaining B:   241129
#   Agent Rewards:       [7.  1.2 8. ]
#   Clay Rewards:       16.2
#   TOT Agent Rewards:       16.2
# Trail 0 Round 501
#   Agent prices:  [2, 1, 3]
#   Demand:        [7 3 6]
#   Remaining B:   240753
#   Agent Rewards:       [4.9 1.8 6. ]
#   Clay Rewards:       12.7
#   TOT Agent Rewards:       12.7
# Trail 0 Round 521
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 7  4 10]
#   Remaining B:   240398
#   Agent Rewards:       [ 4.9  2.4 10. ]
#   Clay Rewards:       17.299999999999997
#   TOT Agent Rewards:       17.299999999999997
# Trail 0 Round 541
#   Agent prices:  [2, 1, 3]
#   Demand:        [11  5 14]
#   Remaining B:   240035
#   Agent Rewards:       [ 7.7  3.  14. ]
#   Clay Rewards:       24.7
#   TOT Agent Rewards:       24.7
# Trail 0 Round 561
#   Agent prices:  [2, 1, 3]
#   Demand:        [5 3 8]
#   Remaining B:   239675
#   Agent Rewards:       [3.5 1.8 8. ]
#   Clay Rewards:       13.3
#   TOT Agent Rewards:       13.3
# Trail 0 Round 581
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 2  1 11]
#   Remaining B:   239316
#   Agent Rewards:       [ 1.4  0.6 11. ]
#   Clay Rewards:       15.0
#   TOT Agent Rewards:       13.0
# Trail 0 Round 601
#   Agent prices:  [2, 1, 3]
#   Demand:        [5 4 9]
#   Remaining B:   238947
#   Agent Rewards:       [3.5 2.4 9. ]
#   Clay Rewards:       14.9
#   TOT Agent Rewards:       14.9
# Trail 0 Round 621
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 8  4 11]
#   Remaining B:   238593
#   Agent Rewards:       [ 5.6  2.4 11. ]
#   Clay Rewards:       19.0
#   TOT Agent Rewards:       19.0
# Trail 0 Round 641
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 7  2 10]
#   Remaining B:   238238
#   Agent Rewards:       [ 4.9  1.2 10. ]
#   Clay Rewards:       16.1
#   TOT Agent Rewards:       16.1
# Trail 0 Round 661
#   Agent prices:  [2, 1, 3]
#   Demand:        [7 3 9]
#   Remaining B:   237891
#   Agent Rewards:       [4.9 1.8 9. ]
#   Clay Rewards:       15.7
#   TOT Agent Rewards:       15.7
# Trail 0 Round 681
#   Agent prices:  [1, 1, 3]
#   Demand:        [16  2  8]
#   Remaining B:   237545
#   Agent Rewards:       [3.2 1.2 8. ]
#   Clay Rewards:       13.399999999999999
#   TOT Agent Rewards:       12.399999999999999
# Trail 0 Round 701
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 9  3 11]
#   Remaining B:   237183
#   Agent Rewards:       [ 6.3  1.8 11. ]
#   Clay Rewards:       19.1
#   TOT Agent Rewards:       19.1
# Trail 0 Round 721
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 8  6 11]
#   Remaining B:   236824
#   Agent Rewards:       [ 5.6  3.6 11. ]
#   Clay Rewards:       20.2
#   TOT Agent Rewards:       20.2
# Trail 0 Round 741
#   Agent prices:  [2, 1, 3]
#   Demand:        [4 2 8]
#   Remaining B:   236470
#   Agent Rewards:       [2.8 1.2 8. ]
#   Clay Rewards:       12.0
#   TOT Agent Rewards:       12.0
# Trail 0 Round 761
#   Agent prices:  [2, 1, 3]
#   Demand:        [6 4 9]
#   Remaining B:   236081
#   Agent Rewards:       [4.2 2.4 9. ]
#   Clay Rewards:       15.6
#   TOT Agent Rewards:       15.6
# Trail 0 Round 781
#   Agent prices:  [2, 1, 3]
#   Demand:        [4 4 6]
#   Remaining B:   235731
#   Agent Rewards:       [2.8 2.4 6. ]
#   Clay Rewards:       11.6
#   TOT Agent Rewards:       11.2
# Trail 0 Round 801
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 5  4 11]
#   Remaining B:   235391
#   Agent Rewards:       [ 3.5  2.4 11. ]
#   Clay Rewards:       16.9
#   TOT Agent Rewards:       16.9
# Trail 0 Round 821
#   Agent prices:  [2, 1, 3]
#   Demand:        [4 2 8]
#   Remaining B:   235025
#   Agent Rewards:       [2.8 1.2 8. ]
#   Clay Rewards:       12.2
#   TOT Agent Rewards:       12.0
# Trail 0 Round 841
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 6  2 10]
#   Remaining B:   234681
#   Agent Rewards:       [ 4.2  1.2 10. ]
#   Clay Rewards:       15.399999999999999
#   TOT Agent Rewards:       15.399999999999999
# Trail 0 Round 861
#   Agent prices:  [2, 1, 3]
#   Demand:        [8 2 9]
#   Remaining B:   234326
#   Agent Rewards:       [5.6 1.2 9. ]
#   Clay Rewards:       15.8
#   TOT Agent Rewards:       15.8
# Trail 0 Round 881
#   Agent prices:  [2, 1, 3]
#   Demand:        [10  2 11]
#   Remaining B:   233987
#   Agent Rewards:       [ 7.   1.2 11. ]
#   Clay Rewards:       19.2
#   TOT Agent Rewards:       19.2
# Trail 0 Round 901
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 6  4 11]
#   Remaining B:   233667
#   Agent Rewards:       [ 4.2  2.4 11. ]
#   Clay Rewards:       17.6
#   TOT Agent Rewards:       17.6
# Trail 0 Round 921
#   Agent prices:  [2, 1, 3]
#   Demand:        [7 4 6]
#   Remaining B:   233321
#   Agent Rewards:       [4.9 2.4 6. ]
#   Clay Rewards:       13.299999999999999
#   TOT Agent Rewards:       13.299999999999999
# Trail 0 Round 941
#   Agent prices:  [2, 1, 3]
#   Demand:        [9 4 8]
#   Remaining B:   232988
#   Agent Rewards:       [6.3 2.4 8. ]
#   Clay Rewards:       16.7
#   TOT Agent Rewards:       16.7
# Trail 0 Round 961
#   Agent prices:  [2, 1, 3]
#   Demand:        [5 3 7]
#   Remaining B:   232628
#   Agent Rewards:       [3.5 1.8 7. ]
#   Clay Rewards:       12.3
#   TOT Agent Rewards:       12.3
# Trail 0 Round 981
#   Agent prices:  [2, 1, 3]
#   Demand:        [5 4 7]
#   Remaining B:   232259
#   Agent Rewards:       [3.5 2.4 7. ]
#   Clay Rewards:       13.399999999999999
#   TOT Agent Rewards:       12.9
# Trail 0 Round 1001
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 5  3 11]
#   Remaining B:   231908
#   Agent Rewards:       [ 3.5  1.8 11. ]
#   Clay Rewards:       16.3
#   TOT Agent Rewards:       16.3
# Trail 0 Round 1021
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 2  4 10]
#   Remaining B:   231548
#   Agent Rewards:       [ 1.4  2.4 10. ]
#   Clay Rewards:       15.399999999999999
#   TOT Agent Rewards:       13.8
# Trail 0 Round 1041
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 6  2 10]
#   Remaining B:   231191
#   Agent Rewards:       [ 4.2  1.2 10. ]
#   Clay Rewards:       15.399999999999999
#   TOT Agent Rewards:       15.399999999999999
# Trail 0 Round 1061
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 3  0 10]
#   Remaining B:   230847
#   Agent Rewards:       [ 2.1  0.  10. ]
#   Clay Rewards:       13.2
#   TOT Agent Rewards:       12.1
# Trail 0 Round 1081
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 1  3 10]
#   Remaining B:   230531
#   Agent Rewards:       [ 0.7  1.8 10. ]
#   Clay Rewards:       15.0
#   TOT Agent Rewards:       12.5
# Trail 0 Round 1101
#   Agent prices:  [2, 1, 3]
#   Demand:        [9 6 9]
#   Remaining B:   230148
#   Agent Rewards:       [6.3 3.6 9. ]
#   Clay Rewards:       18.9
#   TOT Agent Rewards:       18.9
# Trail 0 Round 1121
#   Agent prices:  [2, 1, 3]
#   Demand:        [6 3 9]
#   Remaining B:   229812
#   Agent Rewards:       [4.2 1.8 9. ]
#   Clay Rewards:       15.0
#   TOT Agent Rewards:       15.0
# Trail 0 Round 1141
#   Agent prices:  [2, 1, 3]
#   Demand:        [4 1 7]
#   Remaining B:   229466
#   Agent Rewards:       [2.8 0.6 7. ]
#   Clay Rewards:       10.799999999999999
#   TOT Agent Rewards:       10.4
# Trail 0 Round 1161
#   Agent prices:  [2, 1, 3]
#   Demand:        [6 3 5]
#   Remaining B:   229111
#   Agent Rewards:       [4.2 1.8 5. ]
#   Clay Rewards:       11.0
#   TOT Agent Rewards:       11.0
# Trail 0 Round 1181
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 8  4 12]
#   Remaining B:   228754
#   Agent Rewards:       [ 5.6  2.4 12. ]
#   Clay Rewards:       20.0
#   TOT Agent Rewards:       20.0
# Trail 0 Round 1201
#   Agent prices:  [2, 1, 3]
#   Demand:        [5 0 9]
#   Remaining B:   228394
#   Agent Rewards:       [3.5 0.  9. ]
#   Clay Rewards:       12.5
#   TOT Agent Rewards:       12.5
# Trail 0 Round 1221
#   Agent prices:  [2, 1, 3]
#   Demand:        [6 2 5]
#   Remaining B:   228039
#   Agent Rewards:       [4.2 1.2 5. ]
#   Clay Rewards:       10.399999999999999
#   TOT Agent Rewards:       10.399999999999999
# Trail 0 Round 1241
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 8  5 10]
#   Remaining B:   227681
#   Agent Rewards:       [ 5.6  3.  10. ]
#   Clay Rewards:       18.6
#   TOT Agent Rewards:       18.6
# Trail 0 Round 1261
#   Agent prices:  [2, 1, 3]
#   Demand:        [7 3 7]
#   Remaining B:   227335
#   Agent Rewards:       [4.9 1.8 7. ]
#   Clay Rewards:       13.7
#   TOT Agent Rewards:       13.7
# Trail 0 Round 1281
#   Agent prices:  [2, 1, 3]
#   Demand:        [8 6 9]
#   Remaining B:   226978
#   Agent Rewards:       [5.6 3.6 9. ]
#   Clay Rewards:       18.2
#   TOT Agent Rewards:       18.2
# Trail 0 Round 1301
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 6  4 11]
#   Remaining B:   226636
#   Agent Rewards:       [ 4.2  2.4 11. ]
#   Clay Rewards:       17.6
#   TOT Agent Rewards:       17.6
# Trail 0 Round 1321
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 5  1 12]
#   Remaining B:   226287
#   Agent Rewards:       [ 3.5  0.6 12. ]
#   Clay Rewards:       16.1
#   TOT Agent Rewards:       16.1
# Trail 0 Round 1341
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 6  2 10]
#   Remaining B:   225943
#   Agent Rewards:       [ 4.2  1.2 10. ]
#   Clay Rewards:       15.399999999999999
#   TOT Agent Rewards:       15.399999999999999
# Trail 0 Round 1361
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 5  5 11]
#   Remaining B:   225588
#   Agent Rewards:       [ 3.5  3.  11. ]
#   Clay Rewards:       17.5
#   TOT Agent Rewards:       17.5
# Trail 0 Round 1381
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 6  2 12]
#   Remaining B:   225242
#   Agent Rewards:       [ 4.2  1.2 12. ]
#   Clay Rewards:       17.4
#   TOT Agent Rewards:       17.4
# Trail 0 Round 1401
#   Agent prices:  [2, 1, 3]
#   Demand:        [7 3 9]
#   Remaining B:   224900
#   Agent Rewards:       [4.9 1.8 9. ]
#   Clay Rewards:       15.7
#   TOT Agent Rewards:       15.7
# Trail 0 Round 1421
#   Agent prices:  [2, 1, 3]
#   Demand:        [7 2 9]
#   Remaining B:   224550
#   Agent Rewards:       [4.9 1.2 9. ]
#   Clay Rewards:       15.1
#   TOT Agent Rewards:       15.1
# Trail 0 Round 1441
#   Agent prices:  [2, 1, 3]
#   Demand:        [2 0 9]
#   Remaining B:   224185
#   Agent Rewards:       [1.4 0.  9. ]
#   Clay Rewards:       12.399999999999999
#   TOT Agent Rewards:       10.4
# Trail 0 Round 1461
#   Agent prices:  [2, 1, 3]
#   Demand:        [4 2 7]
#   Remaining B:   223831
#   Agent Rewards:       [2.8 1.2 7. ]
#   Clay Rewards:       11.2
#   TOT Agent Rewards:       11.0
# Trail 0 Round 1481
#   Agent prices:  [2, 1, 3]
#   Demand:        [7 2 8]
#   Remaining B:   223459
#   Agent Rewards:       [4.9 1.2 8. ]
#   Clay Rewards:       14.1
#   TOT Agent Rewards:       14.1
# Trail 0 Round 1501
#   Agent prices:  [2, 1, 3]
#   Demand:        [7 5 8]
#   Remaining B:   223102
#   Agent Rewards:       [4.9 3.  8. ]
#   Clay Rewards:       15.899999999999999
#   TOT Agent Rewards:       15.899999999999999
# Trail 0 Round 1521
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 6  2 10]
#   Remaining B:   222752
#   Agent Rewards:       [ 4.2  1.2 10. ]
#   Clay Rewards:       15.399999999999999
#   TOT Agent Rewards:       15.399999999999999
# Trail 0 Round 1541
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 7  1 12]
#   Remaining B:   222389
#   Agent Rewards:       [ 4.9  0.6 12. ]
#   Clay Rewards:       17.5
#   TOT Agent Rewards:       17.5
# Trail 0 Round 1561
#   Agent prices:  [2, 1, 3]
#   Demand:        [4 5 8]
#   Remaining B:   222011
#   Agent Rewards:       [2.8 3.  8. ]
#   Clay Rewards:       14.2
#   TOT Agent Rewards:       13.8
# Trail 0 Round 1581
#   Agent prices:  [2, 1, 3]
#   Demand:        [4 1 8]
#   Remaining B:   221648
#   Agent Rewards:       [2.8 0.6 8. ]
#   Clay Rewards:       11.4
#   TOT Agent Rewards:       11.4
# Trail 0 Round 1601
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 4  1 11]
#   Remaining B:   221278
#   Agent Rewards:       [ 2.8  0.6 11. ]
#   Clay Rewards:       15.0
#   TOT Agent Rewards:       14.4
# Trail 0 Round 1621
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 5  6 13]
#   Remaining B:   220911
#   Agent Rewards:       [ 3.5  3.6 13. ]
#   Clay Rewards:       20.1
#   TOT Agent Rewards:       20.1
# Trail 0 Round 1641
#   Agent prices:  [2, 1, 3]
#   Demand:        [6 2 7]
#   Remaining B:   220556
#   Agent Rewards:       [4.2 1.2 7. ]
#   Clay Rewards:       12.399999999999999
#   TOT Agent Rewards:       12.399999999999999
# Trail 0 Round 1661
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 5  5 11]
#   Remaining B:   220197
#   Agent Rewards:       [ 3.5  3.  11. ]
#   Clay Rewards:       17.5
#   TOT Agent Rewards:       17.5
# Trail 0 Round 1681
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 8  1 14]
#   Remaining B:   219849
#   Agent Rewards:       [ 5.6  0.6 14. ]
#   Clay Rewards:       20.2
#   TOT Agent Rewards:       20.2
# Trail 0 Round 1701
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 5  4 14]
#   Remaining B:   219468
#   Agent Rewards:       [ 3.5  2.4 14. ]
#   Clay Rewards:       19.9
#   TOT Agent Rewards:       19.9
# Trail 0 Round 1721
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 4  5 12]
#   Remaining B:   219113
#   Agent Rewards:       [ 2.8  3.  12. ]
#   Clay Rewards:       18.0
#   TOT Agent Rewards:       17.8
# Trail 0 Round 1741
#   Agent prices:  [2, 1, 3]
#   Demand:        [4 3 6]
#   Remaining B:   218749
#   Agent Rewards:       [2.8 1.8 6. ]
#   Clay Rewards:       10.6
#   TOT Agent Rewards:       10.6
# Trail 0 Round 1761
#   Agent prices:  [2, 1, 3]
#   Demand:        [9 3 8]
#   Remaining B:   218392
#   Agent Rewards:       [6.3 1.8 8. ]
#   Clay Rewards:       16.1
#   TOT Agent Rewards:       16.1
# Trail 0 Round 1781
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 8  1 11]
#   Remaining B:   218022
#   Agent Rewards:       [ 5.6  0.6 11. ]
#   Clay Rewards:       17.2
#   TOT Agent Rewards:       17.2
# Trail 0 Round 1801
#   Agent prices:  [2, 1, 3]
#   Demand:        [6 2 7]
#   Remaining B:   217671
#   Agent Rewards:       [4.2 1.2 7. ]
#   Clay Rewards:       12.399999999999999
#   TOT Agent Rewards:       12.399999999999999
# Trail 0 Round 1821
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 8  1 11]
#   Remaining B:   217299
#   Agent Rewards:       [ 5.6  0.6 11. ]
#   Clay Rewards:       17.2
#   TOT Agent Rewards:       17.2
# Trail 0 Round 1841
#   Agent prices:  [2, 1, 3]
#   Demand:        [5 3 5]
#   Remaining B:   216935
#   Agent Rewards:       [3.5 1.8 5. ]
#   Clay Rewards:       10.3
#   TOT Agent Rewards:       10.3
# Trail 0 Round 1861
#   Agent prices:  [2, 1, 3]
#   Demand:        [3 3 9]
#   Remaining B:   216590
#   Agent Rewards:       [2.1 1.8 9. ]
#   Clay Rewards:       13.799999999999999
#   TOT Agent Rewards:       12.899999999999999
# Trail 0 Round 1881
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 5  4 13]
#   Remaining B:   216232
#   Agent Rewards:       [ 3.5  2.4 13. ]
#   Clay Rewards:       18.9
#   TOT Agent Rewards:       18.9
# Trail 0 Round 1901
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 8  2 10]
#   Remaining B:   215879
#   Agent Rewards:       [ 5.6  1.2 10. ]
#   Clay Rewards:       16.8
#   TOT Agent Rewards:       16.8
# Trail 0 Round 1921
#   Agent prices:  [2, 1, 3]
#   Demand:        [10  0  6]
#   Remaining B:   215516
#   Agent Rewards:       [7. 0. 6.]
#   Clay Rewards:       13.0
#   TOT Agent Rewards:       13.0
# Trail 0 Round 1941
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 5  4 13]
#   Remaining B:   215165
#   Agent Rewards:       [ 3.5  2.4 13. ]
#   Clay Rewards:       18.9
#   TOT Agent Rewards:       18.9
# Trail 0 Round 1961
#   Agent prices:  [2, 1, 3]
#   Demand:        [9 4 8]
#   Remaining B:   214792
#   Agent Rewards:       [6.3 2.4 8. ]
#   Clay Rewards:       16.7
#   TOT Agent Rewards:       16.7
# Trail 0 Round 1981
#   Agent prices:  [2, 1, 3]
#   Demand:        [7 3 8]
#   Remaining B:   214436
#   Agent Rewards:       [4.9 1.8 8. ]
#   Clay Rewards:       14.7
#   TOT Agent Rewards:       14.7
# Trail 0 Round 2001
#   Agent prices:  [2, 1, 3]
#   Demand:        [6 1 8]
#   Remaining B:   214076
#   Agent Rewards:       [4.2 0.6 8. ]
#   Clay Rewards:       12.799999999999999
#   TOT Agent Rewards:       12.799999999999999
# Trail 0 Round 2021
#   Agent prices:  [2, 1, 3]
#   Demand:        [6 6 9]
#   Remaining B:   213721
#   Agent Rewards:       [4.2 3.6 9. ]
#   Clay Rewards:       16.799999999999997
#   TOT Agent Rewards:       16.799999999999997
# Trail 0 Round 2041
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 3  2 11]
#   Remaining B:   213373
#   Agent Rewards:       [ 2.1  1.2 11. ]
#   Clay Rewards:       15.799999999999999
#   TOT Agent Rewards:       14.3
# Trail 0 Round 2061
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 2  3 11]
#   Remaining B:   213026
#   Agent Rewards:       [ 1.4  1.8 11. ]
#   Clay Rewards:       16.0
#   TOT Agent Rewards:       14.2
# Trail 0 Round 2081
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 9  0 11]
#   Remaining B:   212675
#   Agent Rewards:       [ 6.3  0.  11. ]
#   Clay Rewards:       17.3
#   TOT Agent Rewards:       17.3
# Trail 0 Round 2101
#   Agent prices:  [2, 1, 3]
#   Demand:        [7 3 9]
#   Remaining B:   212352
#   Agent Rewards:       [4.9 1.8 9. ]
#   Clay Rewards:       15.7
#   TOT Agent Rewards:       15.7
# Trail 0 Round 2121
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 4  2 10]
#   Remaining B:   211994
#   Agent Rewards:       [ 2.8  1.2 10. ]
#   Clay Rewards:       14.0
#   TOT Agent Rewards:       14.0
# Trail 0 Round 2141
#   Agent prices:  [2, 1, 3]
#   Demand:        [5 2 5]
#   Remaining B:   211626
#   Agent Rewards:       [3.5 1.2 5. ]
#   Clay Rewards:       9.7
#   TOT Agent Rewards:       9.7
# Trail 0 Round 2161
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 4  4 11]
#   Remaining B:   211277
#   Agent Rewards:       [ 2.8  2.4 11. ]
#   Clay Rewards:       17.0
#   TOT Agent Rewards:       16.2
# Trail 0 Round 2181
#   Agent prices:  [2, 1, 3]
#   Demand:        [7 4 8]
#   Remaining B:   210922
#   Agent Rewards:       [4.9 2.4 8. ]
#   Clay Rewards:       15.299999999999999
#   TOT Agent Rewards:       15.299999999999999
# Trail 0 Round 2201
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 6  2 12]
#   Remaining B:   210555
#   Agent Rewards:       [ 4.2  1.2 12. ]
#   Clay Rewards:       17.4
#   TOT Agent Rewards:       17.4
# Trail 0 Round 2221
#   Agent prices:  [2, 1, 3]
#   Demand:        [5 2 9]
#   Remaining B:   210198
#   Agent Rewards:       [3.5 1.2 9. ]
#   Clay Rewards:       13.7
#   TOT Agent Rewards:       13.7
# Trail 0 Round 2241
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 7  5 10]
#   Remaining B:   209852
#   Agent Rewards:       [ 4.9  3.  10. ]
#   Clay Rewards:       17.9
#   TOT Agent Rewards:       17.9
# Trail 0 Round 2261
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 2  2 12]
#   Remaining B:   209475
#   Agent Rewards:       [ 1.4  1.2 12. ]
#   Clay Rewards:       16.0
#   TOT Agent Rewards:       14.6
# Trail 0 Round 2281
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 5  3 11]
#   Remaining B:   209091
#   Agent Rewards:       [ 3.5  1.8 11. ]
#   Clay Rewards:       16.4
#   TOT Agent Rewards:       16.3
# Trail 0 Round 2301
#   Agent prices:  [2, 1, 3]
#   Demand:        [7 2 8]
#   Remaining B:   208726
#   Agent Rewards:       [4.9 1.2 8. ]
#   Clay Rewards:       14.1
#   TOT Agent Rewards:       14.1
# Trail 0 Round 2321
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 6  3 11]
#   Remaining B:   208375
#   Agent Rewards:       [ 4.2  1.8 11. ]
#   Clay Rewards:       17.0
#   TOT Agent Rewards:       17.0
# Trail 0 Round 2341
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 8  2 12]
#   Remaining B:   208048
#   Agent Rewards:       [ 5.6  1.2 12. ]
#   Clay Rewards:       18.8
#   TOT Agent Rewards:       18.8
# Trail 0 Round 2361
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 9  3 11]
#   Remaining B:   207697
#   Agent Rewards:       [ 6.3  1.8 11. ]
#   Clay Rewards:       19.1
#   TOT Agent Rewards:       19.1
# Trail 0 Round 2381
#   Agent prices:  [2, 1, 3]
#   Demand:        [4 3 9]
#   Remaining B:   207341
#   Agent Rewards:       [2.8 1.8 9. ]
#   Clay Rewards:       13.6
#   TOT Agent Rewards:       13.6
# Trail 0 Round 2401
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 4  2 14]
#   Remaining B:   207010
#   Agent Rewards:       [ 2.8  1.2 14. ]
#   Clay Rewards:       18.4
#   TOT Agent Rewards:       18.0
# Trail 0 Round 2421
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 7  3 10]
#   Remaining B:   206631
#   Agent Rewards:       [ 4.9  1.8 10. ]
#   Clay Rewards:       16.7
#   TOT Agent Rewards:       16.7
# Trail 0 Round 2441
#   Agent prices:  [2, 1, 3]
#   Demand:        [5 2 9]
#   Remaining B:   206293
#   Agent Rewards:       [3.5 1.2 9. ]
#   Clay Rewards:       13.799999999999999
#   TOT Agent Rewards:       13.7
# Trail 0 Round 2461
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 7  1 11]
#   Remaining B:   205918
#   Agent Rewards:       [ 4.9  0.6 11. ]
#   Clay Rewards:       16.5
#   TOT Agent Rewards:       16.5
# Trail 0 Round 2481
#   Agent prices:  [2, 1, 3]
#   Demand:        [5 3 8]
#   Remaining B:   205566
#   Agent Rewards:       [3.5 1.8 8. ]
#   Clay Rewards:       13.3
#   TOT Agent Rewards:       13.3
# Trail 0 Round 2501
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 5  4 15]
#   Remaining B:   205184
#   Agent Rewards:       [ 3.5  2.4 15. ]
#   Clay Rewards:       20.9
#   TOT Agent Rewards:       20.9
# Trail 0 Round 2521
#   Agent prices:  [2, 1, 3]
#   Demand:        [5 2 7]
#   Remaining B:   204857
#   Agent Rewards:       [3.5 1.2 7. ]
#   Clay Rewards:       11.7
#   TOT Agent Rewards:       11.7
# Trail 0 Round 2541
#   Agent prices:  [2, 1, 3]
#   Demand:        [5 1 7]
#   Remaining B:   204489
#   Agent Rewards:       [3.5 0.6 7. ]
#   Clay Rewards:       11.1
#   TOT Agent Rewards:       11.1
# Trail 0 Round 2561
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 5  2 11]
#   Remaining B:   204125
#   Agent Rewards:       [ 3.5  1.2 11. ]
#   Clay Rewards:       15.7
#   TOT Agent Rewards:       15.7
# Trail 0 Round 2581
#   Agent prices:  [2, 1, 3]
#   Demand:        [5 6 7]
#   Remaining B:   203772
#   Agent Rewards:       [3.5 3.6 7. ]
#   Clay Rewards:       14.1
#   TOT Agent Rewards:       14.1
# Trail 0 Round 2601
#   Agent prices:  [2, 1, 3]
#   Demand:        [8 4 8]
#   Remaining B:   203405
#   Agent Rewards:       [5.6 2.4 8. ]
#   Clay Rewards:       16.0
#   TOT Agent Rewards:       16.0
# Trail 0 Round 2621
#   Agent prices:  [2, 1, 3]
#   Demand:        [4 4 6]
#   Remaining B:   203067
#   Agent Rewards:       [2.8 2.4 6. ]
#   Clay Rewards:       11.799999999999999
#   TOT Agent Rewards:       11.2
# Trail 0 Round 2641
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 6  4 11]
#   Remaining B:   202692
#   Agent Rewards:       [ 4.2  2.4 11. ]
#   Clay Rewards:       17.6
#   TOT Agent Rewards:       17.6
# Trail 0 Round 2661
#   Agent prices:  [2, 1, 3]
#   Demand:        [6 1 7]
#   Remaining B:   202360
#   Agent Rewards:       [4.2 0.6 7. ]
#   Clay Rewards:       11.799999999999999
#   TOT Agent Rewards:       11.799999999999999
# Trail 0 Round 2681
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 5  2 10]
#   Remaining B:   201994
#   Agent Rewards:       [ 3.5  1.2 10. ]
#   Clay Rewards:       14.7
#   TOT Agent Rewards:       14.7
# Trail 0 Round 2701
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 8  2 11]
#   Remaining B:   201638
#   Agent Rewards:       [ 5.6  1.2 11. ]
#   Clay Rewards:       17.8
#   TOT Agent Rewards:       17.8
# Trail 0 Round 2721
#   Agent prices:  [2, 1, 3]
#   Demand:        [3 3 5]
#   Remaining B:   201279
#   Agent Rewards:       [2.1 1.8 5. ]
#   Clay Rewards:       10.0
#   TOT Agent Rewards:       8.899999999999999
# Trail 0 Round 2741
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 6  4 12]
#   Remaining B:   200937
#   Agent Rewards:       [ 4.2  2.4 12. ]
#   Clay Rewards:       18.6
#   TOT Agent Rewards:       18.6
# Trail 0 Round 2761
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 3  2 12]
#   Remaining B:   200601
#   Agent Rewards:       [ 2.1  1.2 12. ]
#   Clay Rewards:       16.4
#   TOT Agent Rewards:       15.3
# Trail 0 Round 2781
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 6  0 10]
#   Remaining B:   200252
#   Agent Rewards:       [ 4.2  0.  10. ]
#   Clay Rewards:       14.2
#   TOT Agent Rewards:       14.2
# Trail 0 Round 2801
#   Agent prices:  [2, 1, 3]
#   Demand:        [6 3 8]
#   Remaining B:   199909
#   Agent Rewards:       [4.2 1.8 8. ]
#   Clay Rewards:       14.0
#   TOT Agent Rewards:       14.0
# Trail 0 Round 2821
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 7  1 11]
#   Remaining B:   199523
#   Agent Rewards:       [ 4.9  0.6 11. ]
#   Clay Rewards:       16.5
#   TOT Agent Rewards:       16.5
# Trail 0 Round 2841
#   Agent prices:  [2, 1, 3]
#   Demand:        [7 2 9]
#   Remaining B:   199144
#   Agent Rewards:       [4.9 1.2 9. ]
#   Clay Rewards:       15.1
#   TOT Agent Rewards:       15.1
# Trail 0 Round 2861
#   Agent prices:  [2, 1, 3]
#   Demand:        [8 3 7]
#   Remaining B:   198789
#   Agent Rewards:       [5.6 1.8 7. ]
#   Clay Rewards:       14.399999999999999
#   TOT Agent Rewards:       14.399999999999999
# Trail 0 Round 2881
#   Agent prices:  [2, 1, 3]
#   Demand:        [5 2 9]
#   Remaining B:   198443
#   Agent Rewards:       [3.5 1.2 9. ]
#   Clay Rewards:       13.799999999999999
#   TOT Agent Rewards:       13.7
# Trail 0 Round 2901
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 6  1 10]
#   Remaining B:   198082
#   Agent Rewards:       [ 4.2  0.6 10. ]
#   Clay Rewards:       14.799999999999999
#   TOT Agent Rewards:       14.799999999999999
# Trail 0 Round 2921
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 8  1 11]
#   Remaining B:   197719
#   Agent Rewards:       [ 5.6  0.6 11. ]
#   Clay Rewards:       17.2
#   TOT Agent Rewards:       17.2
# Trail 0 Round 2941
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 1  6 13]
#   Remaining B:   197355
#   Agent Rewards:       [ 0.7  3.6 13. ]
#   Clay Rewards:       19.2
#   TOT Agent Rewards:       17.3
# Trail 0 Round 2961
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 6  1 11]
#   Remaining B:   196962
#   Agent Rewards:       [ 4.2  0.6 11. ]
#   Clay Rewards:       15.799999999999999
#   TOT Agent Rewards:       15.799999999999999
# Trail 0 Round 2981
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 9  3 12]
#   Remaining B:   196587
#   Agent Rewards:       [ 6.3  1.8 12. ]
#   Clay Rewards:       20.1
#   TOT Agent Rewards:       20.1
# Trail 0 Round 3001
#   Agent prices:  [2, 1, 3]
#   Demand:        [8 3 5]
#   Remaining B:   196236
#   Agent Rewards:       [5.6 1.8 5. ]
#   Clay Rewards:       12.399999999999999
#   TOT Agent Rewards:       12.399999999999999
# Trail 0 Round 3021
#   Agent prices:  [2, 1, 3]
#   Demand:        [6 1 6]
#   Remaining B:   195901
#   Agent Rewards:       [4.2 0.6 6. ]
#   Clay Rewards:       10.799999999999999
#   TOT Agent Rewards:       10.799999999999999
# Trail 0 Round 3041
#   Agent prices:  [2, 1, 3]
#   Demand:        [4 5 7]
#   Remaining B:   195531
#   Agent Rewards:       [2.8 3.  7. ]
#   Clay Rewards:       13.399999999999999
#   TOT Agent Rewards:       12.8
# Trail 0 Round 3061
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 8  2 11]
#   Remaining B:   195160
#   Agent Rewards:       [ 5.6  1.2 11. ]
#   Clay Rewards:       17.8
#   TOT Agent Rewards:       17.8
# Trail 0 Round 3081
#   Agent prices:  [2, 1, 3]
#   Demand:        [7 4 8]
#   Remaining B:   194799
#   Agent Rewards:       [4.9 2.4 8. ]
#   Clay Rewards:       15.299999999999999
#   TOT Agent Rewards:       15.299999999999999
# Trail 0 Round 3101
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 6  0 11]
#   Remaining B:   194446
#   Agent Rewards:       [ 4.2  0.  11. ]
#   Clay Rewards:       15.2
#   TOT Agent Rewards:       15.2
# Trail 0 Round 3121
#   Agent prices:  [2, 1, 3]
#   Demand:        [5 5 9]
#   Remaining B:   194121
#   Agent Rewards:       [3.5 3.  9. ]
#   Clay Rewards:       15.5
#   TOT Agent Rewards:       15.5
# Trail 0 Round 3141
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 4  3 10]
#   Remaining B:   193766
#   Agent Rewards:       [ 2.8  1.8 10. ]
#   Clay Rewards:       15.2
#   TOT Agent Rewards:       14.6
# Trail 0 Round 3161
#   Agent prices:  [2, 1, 3]
#   Demand:        [5 1 9]
#   Remaining B:   193430
#   Agent Rewards:       [3.5 0.6 9. ]
#   Clay Rewards:       13.1
#   TOT Agent Rewards:       13.1
# Trail 0 Round 3181
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 1  1 11]
#   Remaining B:   193085
#   Agent Rewards:       [ 0.7  0.6 11. ]
#   Clay Rewards:       15.2
#   TOT Agent Rewards:       12.3
# Trail 0 Round 3201
#   Agent prices:  [2, 1, 3]
#   Demand:        [9 8 9]
#   Remaining B:   192723
#   Agent Rewards:       [6.3 4.8 9. ]
#   Clay Rewards:       20.1
#   TOT Agent Rewards:       20.1
# Trail 0 Round 3221
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 5  4 12]
#   Remaining B:   192365
#   Agent Rewards:       [ 3.5  2.4 12. ]
#   Clay Rewards:       17.9
#   TOT Agent Rewards:       17.9
# Trail 0 Round 3241
#   Agent prices:  [2, 1, 3]
#   Demand:        [8 3 9]
#   Remaining B:   192007
#   Agent Rewards:       [5.6 1.8 9. ]
#   Clay Rewards:       16.4
#   TOT Agent Rewards:       16.4
# Trail 0 Round 3261
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 9  4 11]
#   Remaining B:   191641
#   Agent Rewards:       [ 6.3  2.4 11. ]
#   Clay Rewards:       19.7
#   TOT Agent Rewards:       19.7
# Trail 0 Round 3281
#   Agent prices:  [2, 1, 3]
#   Demand:        [3 2 6]
#   Remaining B:   191309
#   Agent Rewards:       [2.1 1.2 6. ]
#   Clay Rewards:       10.799999999999999
#   TOT Agent Rewards:       9.3
# Trail 0 Round 3301
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 4  2 11]
#   Remaining B:   190957
#   Agent Rewards:       [ 2.8  1.2 11. ]
#   Clay Rewards:       15.0
#   TOT Agent Rewards:       15.0
# Trail 0 Round 3321
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 9  1 10]
#   Remaining B:   190570
#   Agent Rewards:       [ 6.3  0.6 10. ]
#   Clay Rewards:       16.9
#   TOT Agent Rewards:       16.9
# Trail 0 Round 3341
#   Agent prices:  [2, 1, 3]
#   Demand:        [6 1 7]
#   Remaining B:   190204
#   Agent Rewards:       [4.2 0.6 7. ]
#   Clay Rewards:       11.799999999999999
#   TOT Agent Rewards:       11.799999999999999
# Trail 0 Round 3361
#   Agent prices:  [2, 1, 3]
#   Demand:        [6 4 7]
#   Remaining B:   189849
#   Agent Rewards:       [4.2 2.4 7. ]
#   Clay Rewards:       13.6
#   TOT Agent Rewards:       13.6
# Trail 0 Round 3381
#   Agent prices:  [2, 1, 3]
#   Demand:        [6 2 8]
#   Remaining B:   189506
#   Agent Rewards:       [4.2 1.2 8. ]
#   Clay Rewards:       13.399999999999999
#   TOT Agent Rewards:       13.399999999999999
# Trail 0 Round 3401
#   Agent prices:  [2, 1, 3]
#   Demand:        [1 5 6]
#   Remaining B:   189141
#   Agent Rewards:       [0.7 3.  6. ]
#   Clay Rewards:       11.799999999999999
#   TOT Agent Rewards:       9.7
# Trail 0 Round 3421
#   Agent prices:  [2, 1, 3]
#   Demand:        [8 0 8]
#   Remaining B:   188772
#   Agent Rewards:       [5.6 0.  8. ]
#   Clay Rewards:       13.6
#   TOT Agent Rewards:       13.6
# Trail 0 Round 3441
#   Agent prices:  [2, 1, 3]
#   Demand:        [6 3 9]
#   Remaining B:   188440
#   Agent Rewards:       [4.2 1.8 9. ]
#   Clay Rewards:       15.0
#   TOT Agent Rewards:       15.0
# Trail 0 Round 3461
#   Agent prices:  [2, 1, 3]
#   Demand:        [6 4 7]
#   Remaining B:   188077
#   Agent Rewards:       [4.2 2.4 7. ]
#   Clay Rewards:       13.6
#   TOT Agent Rewards:       13.6
# Trail 0 Round 3481
#   Agent prices:  [2, 1, 3]
#   Demand:        [7 4 8]
#   Remaining B:   187708
#   Agent Rewards:       [4.9 2.4 8. ]
#   Clay Rewards:       15.299999999999999
#   TOT Agent Rewards:       15.299999999999999
# Trail 0 Round 3501
#   Agent prices:  [2, 1, 3]
#   Demand:        [4 3 7]
#   Remaining B:   187364
#   Agent Rewards:       [2.8 1.8 7. ]
#   Clay Rewards:       11.6
#   TOT Agent Rewards:       11.6
# Trail 0 Round 3521
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 8  5 13]
#   Remaining B:   187013
#   Agent Rewards:       [ 5.6  3.  13. ]
#   Clay Rewards:       21.6
#   TOT Agent Rewards:       21.6
# Trail 0 Round 3541
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 3  1 10]
#   Remaining B:   186634
#   Agent Rewards:       [ 2.1  0.6 10. ]
#   Clay Rewards:       13.799999999999999
#   TOT Agent Rewards:       12.7
# Trail 0 Round 3561
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 9  6 12]
#   Remaining B:   186256
#   Agent Rewards:       [ 6.3  3.6 12. ]
#   Clay Rewards:       21.9
#   TOT Agent Rewards:       21.9
# Trail 0 Round 3581
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 6  2 11]
#   Remaining B:   185880
#   Agent Rewards:       [ 4.2  1.2 11. ]
#   Clay Rewards:       16.4
#   TOT Agent Rewards:       16.4
# Trail 0 Round 3601
#   Agent prices:  [2, 1, 3]
#   Demand:        [9 2 4]
#   Remaining B:   185531
#   Agent Rewards:       [6.3 1.2 4. ]
#   Clay Rewards:       11.5
#   TOT Agent Rewards:       11.5
# Trail 0 Round 3621
#   Agent prices:  [2, 1, 3]
#   Demand:        [7 4 9]
#   Remaining B:   185159
#   Agent Rewards:       [4.9 2.4 9. ]
#   Clay Rewards:       16.299999999999997
#   TOT Agent Rewards:       16.299999999999997
# Trail 0 Round 3641
#   Agent prices:  [2, 1, 3]
#   Demand:        [6 3 9]
#   Remaining B:   184812
#   Agent Rewards:       [4.2 1.8 9. ]
#   Clay Rewards:       15.0
#   TOT Agent Rewards:       15.0
# Trail 0 Round 3661
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 2  4 12]
#   Remaining B:   184444
#   Agent Rewards:       [ 1.4  2.4 12. ]
#   Clay Rewards:       17.6
#   TOT Agent Rewards:       15.8
# Trail 0 Round 3681
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 5  1 13]
#   Remaining B:   184111
#   Agent Rewards:       [ 3.5  0.6 13. ]
#   Clay Rewards:       17.1
#   TOT Agent Rewards:       17.1
# Trail 0 Round 3701
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 5  0 10]
#   Remaining B:   183771
#   Agent Rewards:       [ 3.5  0.  10. ]
#   Clay Rewards:       13.5
#   TOT Agent Rewards:       13.5
# Trail 0 Round 3721
#   Agent prices:  [2, 1, 3]
#   Demand:        [7 1 9]
#   Remaining B:   183417
#   Agent Rewards:       [4.9 0.6 9. ]
#   Clay Rewards:       14.5
#   TOT Agent Rewards:       14.5
# Trail 0 Round 3741
#   Agent prices:  [2, 1, 3]
#   Demand:        [7 2 8]
#   Remaining B:   183056
#   Agent Rewards:       [4.9 1.2 8. ]
#   Clay Rewards:       14.1
#   TOT Agent Rewards:       14.1
# Trail 0 Round 3761
#   Agent prices:  [2, 1, 3]
#   Demand:        [7 0 6]
#   Remaining B:   182698
#   Agent Rewards:       [4.9 0.  6. ]
#   Clay Rewards:       10.899999999999999
#   TOT Agent Rewards:       10.899999999999999
# Trail 0 Round 3781
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 6  3 12]
#   Remaining B:   182313
#   Agent Rewards:       [ 4.2  1.8 12. ]
#   Clay Rewards:       18.0
#   TOT Agent Rewards:       18.0
# Trail 0 Round 3801
#   Agent prices:  [2, 1, 3]
#   Demand:        [3 2 7]
#   Remaining B:   181986
#   Agent Rewards:       [2.1 1.2 7. ]
#   Clay Rewards:       11.2
#   TOT Agent Rewards:       10.3
# Trail 0 Round 3821
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 5  2 11]
#   Remaining B:   181617
#   Agent Rewards:       [ 3.5  1.2 11. ]
#   Clay Rewards:       15.7
#   TOT Agent Rewards:       15.7
# Trail 0 Round 3841
#   Agent prices:  [2, 1, 3]
#   Demand:        [9 3 9]
#   Remaining B:   181246
#   Agent Rewards:       [6.3 1.8 9. ]
#   Clay Rewards:       17.1
#   TOT Agent Rewards:       17.1
# Trail 0 Round 3861
#   Agent prices:  [2, 1, 3]
#   Demand:        [7 4 9]
#   Remaining B:   180870
#   Agent Rewards:       [4.9 2.4 9. ]
#   Clay Rewards:       16.299999999999997
#   TOT Agent Rewards:       16.299999999999997
# Trail 0 Round 3881
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 4  3 11]
#   Remaining B:   180495
#   Agent Rewards:       [ 2.8  1.8 11. ]
#   Clay Rewards:       15.799999999999999
#   TOT Agent Rewards:       15.6
# Trail 0 Round 3901
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 4  3 10]
#   Remaining B:   180123
#   Agent Rewards:       [ 2.8  1.8 10. ]
#   Clay Rewards:       14.799999999999999
#   TOT Agent Rewards:       14.6
# Trail 0 Round 3921
#   Agent prices:  [2, 1, 3]
#   Demand:        [6 2 7]
#   Remaining B:   179746
#   Agent Rewards:       [4.2 1.2 7. ]
#   Clay Rewards:       12.399999999999999
#   TOT Agent Rewards:       12.399999999999999
# Trail 0 Round 3941
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 6  5 10]
#   Remaining B:   179379
#   Agent Rewards:       [ 4.2  3.  10. ]
#   Clay Rewards:       17.2
#   TOT Agent Rewards:       17.2
# Trail 0 Round 3961
#   Agent prices:  [2, 1, 3]
#   Demand:        [9 2 7]
#   Remaining B:   179012
#   Agent Rewards:       [6.3 1.2 7. ]
#   Clay Rewards:       14.5
#   TOT Agent Rewards:       14.5
# Trail 0 Round 3981
#   Agent prices:  [2, 1, 3]
#   Demand:        [5 3 8]
#   Remaining B:   178650
#   Agent Rewards:       [3.5 1.8 8. ]
#   Clay Rewards:       13.3
#   TOT Agent Rewards:       13.3
# Trail 0 Round 4001
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 6  3 11]
#   Remaining B:   178271
#   Agent Rewards:       [ 4.2  1.8 11. ]
#   Clay Rewards:       17.0
#   TOT Agent Rewards:       17.0
# Trail 0 Round 4021
#   Agent prices:  [2, 1, 3]
#   Demand:        [5 1 8]
#   Remaining B:   177915
#   Agent Rewards:       [3.5 0.6 8. ]
#   Clay Rewards:       12.1
#   TOT Agent Rewards:       12.1
# Trail 0 Round 4041
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 7  5 10]
#   Remaining B:   177553
#   Agent Rewards:       [ 4.9  3.  10. ]
#   Clay Rewards:       17.9
#   TOT Agent Rewards:       17.9
# Trail 0 Round 4061
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 6  2 11]
#   Remaining B:   177198
#   Agent Rewards:       [ 4.2  1.2 11. ]
#   Clay Rewards:       16.4
#   TOT Agent Rewards:       16.4
# Trail 0 Round 4081
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 6  5 13]
#   Remaining B:   176830
#   Agent Rewards:       [ 4.2  3.  13. ]
#   Clay Rewards:       20.2
#   TOT Agent Rewards:       20.2
# Trail 0 Round 4101
#   Agent prices:  [2, 1, 3]
#   Demand:        [3 5 9]
#   Remaining B:   176457
#   Agent Rewards:       [2.1 3.  9. ]
#   Clay Rewards:       15.0
#   TOT Agent Rewards:       14.1
# Trail 0 Round 4121
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 3  3 11]
#   Remaining B:   176106
#   Agent Rewards:       [ 2.1  1.8 11. ]
#   Clay Rewards:       15.799999999999999
#   TOT Agent Rewards:       14.899999999999999
# Trail 0 Round 4141
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 1  3 10]
#   Remaining B:   175742
#   Agent Rewards:       [ 0.7  1.8 10. ]
#   Clay Rewards:       15.2
#   TOT Agent Rewards:       12.5
# Trail 0 Round 4161
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 7  1 10]
#   Remaining B:   175359
#   Agent Rewards:       [ 4.9  0.6 10. ]
#   Clay Rewards:       15.5
#   TOT Agent Rewards:       15.5
# Trail 0 Round 4181
#   Agent prices:  [2, 1, 3]
#   Demand:        [5 3 5]
#   Remaining B:   175011
#   Agent Rewards:       [3.5 1.8 5. ]
#   Clay Rewards:       10.3
#   TOT Agent Rewards:       10.3
# Trail 0 Round 4201
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 5  2 11]
#   Remaining B:   174637
#   Agent Rewards:       [ 3.5  1.2 11. ]
#   Clay Rewards:       15.7
#   TOT Agent Rewards:       15.7
# Trail 0 Round 4221
#   Agent prices:  [2, 1, 3]
#   Demand:        [5 2 6]
#   Remaining B:   174288
#   Agent Rewards:       [3.5 1.2 6. ]
#   Clay Rewards:       10.7
#   TOT Agent Rewards:       10.7
# Trail 0 Round 4241
#   Agent prices:  [2, 1, 3]
#   Demand:        [4 3 6]
#   Remaining B:   173917
#   Agent Rewards:       [2.8 1.8 6. ]
#   Clay Rewards:       10.6
#   TOT Agent Rewards:       10.6
# Trail 0 Round 4261
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 5  1 10]
#   Remaining B:   173576
#   Agent Rewards:       [ 3.5  0.6 10. ]
#   Clay Rewards:       14.1
#   TOT Agent Rewards:       14.1
# Trail 0 Round 4281
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 6  3 10]
#   Remaining B:   173215
#   Agent Rewards:       [ 4.2  1.8 10. ]
#   Clay Rewards:       16.0
#   TOT Agent Rewards:       16.0
# Trail 0 Round 4301
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 4  4 13]
#   Remaining B:   172849
#   Agent Rewards:       [ 2.8  2.4 13. ]
#   Clay Rewards:       18.799999999999997
#   TOT Agent Rewards:       18.2
# Trail 0 Round 4321
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 3  2 10]
#   Remaining B:   172478
#   Agent Rewards:       [ 2.1  1.2 10. ]
#   Clay Rewards:       14.2
#   TOT Agent Rewards:       13.3
# Trail 0 Round 4341
#   Agent prices:  [2, 1, 3]
#   Demand:        [7 2 8]
#   Remaining B:   172118
#   Agent Rewards:       [4.9 1.2 8. ]
#   Clay Rewards:       14.1
#   TOT Agent Rewards:       14.1
# Trail 0 Round 4361
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 7  4 12]
#   Remaining B:   171775
#   Agent Rewards:       [ 4.9  2.4 12. ]
#   Clay Rewards:       19.299999999999997
#   TOT Agent Rewards:       19.299999999999997
# Trail 0 Round 4381
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 4  3 13]
#   Remaining B:   171412
#   Agent Rewards:       [ 2.8  1.8 13. ]
#   Clay Rewards:       18.0
#   TOT Agent Rewards:       17.6
# Trail 0 Round 4401
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 5  5 14]
#   Remaining B:   171067
#   Agent Rewards:       [ 3.5  3.  14. ]
#   Clay Rewards:       20.6
#   TOT Agent Rewards:       20.5
# Trail 0 Round 4421
#   Agent prices:  [2, 1, 3]
#   Demand:        [5 1 9]
#   Remaining B:   170715
#   Agent Rewards:       [3.5 0.6 9. ]
#   Clay Rewards:       13.1
#   TOT Agent Rewards:       13.1
# Trail 0 Round 4441
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 7  5 12]
#   Remaining B:   170358
#   Agent Rewards:       [ 4.9  3.  12. ]
#   Clay Rewards:       19.9
#   TOT Agent Rewards:       19.9
# Trail 0 Round 4461
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 7  1 10]
#   Remaining B:   169976
#   Agent Rewards:       [ 4.9  0.6 10. ]
#   Clay Rewards:       15.5
#   TOT Agent Rewards:       15.5
# Trail 0 Round 4481
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 5  3 10]
#   Remaining B:   169600
#   Agent Rewards:       [ 3.5  1.8 10. ]
#   Clay Rewards:       15.3
#   TOT Agent Rewards:       15.3
# Trail 0 Round 4501
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 3  2 11]
#   Remaining B:   169243
#   Agent Rewards:       [ 2.1  1.2 11. ]
#   Clay Rewards:       15.0
#   TOT Agent Rewards:       14.3
# Trail 0 Round 4521
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 7  3 12]
#   Remaining B:   168884
#   Agent Rewards:       [ 4.9  1.8 12. ]
#   Clay Rewards:       18.7
#   TOT Agent Rewards:       18.7
# Trail 0 Round 4541
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 3  1 10]
#   Remaining B:   168526
#   Agent Rewards:       [ 2.1  0.6 10. ]
#   Clay Rewards:       13.399999999999999
#   TOT Agent Rewards:       12.7
# Trail 0 Round 4561
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 6  2 13]
#   Remaining B:   168173
#   Agent Rewards:       [ 4.2  1.2 13. ]
#   Clay Rewards:       18.4
#   TOT Agent Rewards:       18.4
# Trail 0 Round 4581
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 5  2 11]
#   Remaining B:   167825
#   Agent Rewards:       [ 3.5  1.2 11. ]
#   Clay Rewards:       15.7
#   TOT Agent Rewards:       15.7
# Trail 0 Round 4601
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 5  1 10]
#   Remaining B:   167443
#   Agent Rewards:       [ 3.5  0.6 10. ]
#   Clay Rewards:       14.1
#   TOT Agent Rewards:       14.1
# Trail 0 Round 4621
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 3  3 10]
#   Remaining B:   167100
#   Agent Rewards:       [ 2.1  1.8 10. ]
#   Clay Rewards:       14.399999999999999
#   TOT Agent Rewards:       13.899999999999999
# Trail 0 Round 4641
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 7  5 11]
#   Remaining B:   166734
#   Agent Rewards:       [ 4.9  3.  11. ]
#   Clay Rewards:       18.9
#   TOT Agent Rewards:       18.9
# Trail 0 Round 4661
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 8  1 10]
#   Remaining B:   166369
#   Agent Rewards:       [ 5.6  0.6 10. ]
#   Clay Rewards:       16.2
#   TOT Agent Rewards:       16.2
# Trail 0 Round 4681
#   Agent prices:  [2, 1, 3]
#   Demand:        [5 1 8]
#   Remaining B:   166015
#   Agent Rewards:       [3.5 0.6 8. ]
#   Clay Rewards:       12.1
#   TOT Agent Rewards:       12.1
# Trail 0 Round 4701
#   Agent prices:  [2, 1, 3]
#   Demand:        [6 4 9]
#   Remaining B:   165649
#   Agent Rewards:       [4.2 2.4 9. ]
#   Clay Rewards:       15.6
#   TOT Agent Rewards:       15.6
# Trail 0 Round 4721
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 4  4 11]
#   Remaining B:   165304
#   Agent Rewards:       [ 2.8  2.4 11. ]
#   Clay Rewards:       16.4
#   TOT Agent Rewards:       16.2
# Trail 0 Round 4741
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 7  5 10]
#   Remaining B:   164921
#   Agent Rewards:       [ 4.9  3.  10. ]
#   Clay Rewards:       17.9
#   TOT Agent Rewards:       17.9
# Trail 0 Round 4761
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 8  3 12]
#   Remaining B:   164558
#   Agent Rewards:       [ 5.6  1.8 12. ]
#   Clay Rewards:       19.4
#   TOT Agent Rewards:       19.4
# Trail 0 Round 4781
#   Agent prices:  [2, 1, 3]
#   Demand:        [1 2 9]
#   Remaining B:   164203
#   Agent Rewards:       [0.7 1.2 9. ]
#   Clay Rewards:       13.2
#   TOT Agent Rewards:       10.9
# Trail 0 Round 4801
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 5  3 10]
#   Remaining B:   163874
#   Agent Rewards:       [ 3.5  1.8 10. ]
#   Clay Rewards:       15.3
# ...
#   Demand:        [ 5  2 10]
#   Remaining B:   95233
#   Agent Rewards:       [ 3.5  1.2 10. ]
#   Clay Rewards:       14.799999999999999
#   TOT Agent Rewards:       14.7
# Trail 0 Round 8661
#   Agent prices:  [2, 1, 3]
#   Demand:        [8 3 9]
#   Remaining B:   94876
#   Agent Rewards:       [5.6 1.8 9. ]
#   Clay Rewards:       16.4
#   TOT Agent Rewards:       16.4
# Trail 0 Round 8681
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 4  2 11]
#   Remaining B:   94537
#   Agent Rewards:       [ 2.8  1.2 11. ]
#   Clay Rewards:       15.2
#   TOT Agent Rewards:       15.0
# Trail 0 Round 8701
#   Agent prices:  [2, 1, 3]
#   Demand:        [5 1 8]
#   Remaining B:   94176
#   Agent Rewards:       [3.5 0.6 8. ]
#   Clay Rewards:       12.1
#   TOT Agent Rewards:       12.1
# Trail 0 Round 8721
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 4  1 11]
#   Remaining B:   93800
#   Agent Rewards:       [ 2.8  0.6 11. ]
#   Clay Rewards:       15.0
#   TOT Agent Rewards:       14.4
# Trail 0 Round 8741
#   Agent prices:  [2, 1, 3]
#   Demand:        [6 5 6]
#   Remaining B:   93424
#   Agent Rewards:       [4.2 3.  6. ]
#   Clay Rewards:       13.2
#   TOT Agent Rewards:       13.2
# Trail 0 Round 8761
#   Agent prices:  [2, 1, 3]
#   Demand:        [5 1 9]
#   Remaining B:   93070
#   Agent Rewards:       [3.5 0.6 9. ]
#   Clay Rewards:       13.1
#   TOT Agent Rewards:       13.1
# Trail 0 Round 8781
#   Agent prices:  [2, 1, 3]
#   Demand:        [4 0 8]
#   Remaining B:   92714
#   Agent Rewards:       [2.8 0.  8. ]
#   Clay Rewards:       11.2
#   TOT Agent Rewards:       10.8
# Trail 0 Round 8801
#   Agent prices:  [2, 1, 3]
#   Demand:        [5 3 7]
#   Remaining B:   92353
#   Agent Rewards:       [3.5 1.8 7. ]
#   Clay Rewards:       12.3
#   TOT Agent Rewards:       12.3
# Trail 0 Round 8821
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 3  4 14]
#   Remaining B:   91985
#   Agent Rewards:       [ 2.1  2.4 14. ]
#   Clay Rewards:       19.6
#   TOT Agent Rewards:       18.5
# Trail 0 Round 8841
#   Agent prices:  [2, 1, 3]
#   Demand:        [6 1 9]
#   Remaining B:   91631
#   Agent Rewards:       [4.2 0.6 9. ]
#   Clay Rewards:       13.799999999999999
#   TOT Agent Rewards:       13.799999999999999
# Trail 0 Round 8861
#   Agent prices:  [2, 1, 3]
#   Demand:        [7 3 9]
#   Remaining B:   91255
#   Agent Rewards:       [4.9 1.8 9. ]
#   Clay Rewards:       15.7
#   TOT Agent Rewards:       15.7
# Trail 0 Round 8881
#   Agent prices:  [2, 1, 3]
#   Demand:        [5 3 9]
#   Remaining B:   90919
#   Agent Rewards:       [3.5 1.8 9. ]
#   Clay Rewards:       14.3
#   TOT Agent Rewards:       14.3
# Trail 0 Round 8901
#   Agent prices:  [2, 1, 3]
#   Demand:        [5 1 9]
#   Remaining B:   90558
#   Agent Rewards:       [3.5 0.6 9. ]
#   Clay Rewards:       13.2
#   TOT Agent Rewards:       13.1
# Trail 0 Round 8921
#   Agent prices:  [2, 1, 3]
#   Demand:        [4 2 7]
#   Remaining B:   90173
#   Agent Rewards:       [2.8 1.2 7. ]
#   Clay Rewards:       11.0
#   TOT Agent Rewards:       11.0
# Trail 0 Round 8941
#   Agent prices:  [2, 1, 3]
#   Demand:        [7 4 9]
#   Remaining B:   89812
#   Agent Rewards:       [4.9 2.4 9. ]
#   Clay Rewards:       16.299999999999997
#   TOT Agent Rewards:       16.299999999999997
# Trail 0 Round 8961
#   Agent prices:  [2, 1, 3]
#   Demand:        [7 1 8]
#   Remaining B:   89487
#   Agent Rewards:       [4.9 0.6 8. ]
#   Clay Rewards:       13.5
#   TOT Agent Rewards:       13.5
# Trail 0 Round 8981
#   Agent prices:  [2, 1, 3]
#   Demand:        [8 2 5]
#   Remaining B:   89168
#   Agent Rewards:       [5.6 1.2 5. ]
#   Clay Rewards:       11.8
#   TOT Agent Rewards:       11.8
# Trail 0 Round 9001
#   Agent prices:  [2, 1, 3]
#   Demand:        [5 2 7]
#   Remaining B:   88813
#   Agent Rewards:       [3.5 1.2 7. ]
#   Clay Rewards:       11.7
#   TOT Agent Rewards:       11.7
# Trail 0 Round 9021
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 8  3 14]
#   Remaining B:   88456
#   Agent Rewards:       [ 5.6  1.8 14. ]
#   Clay Rewards:       21.4
#   TOT Agent Rewards:       21.4
# Trail 0 Round 9041
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 5  3 11]
#   Remaining B:   88083
#   Agent Rewards:       [ 3.5  1.8 11. ]
#   Clay Rewards:       16.3
#   TOT Agent Rewards:       16.3
# Trail 0 Round 9061
#   Agent prices:  [2, 1, 3]
#   Demand:        [8 2 9]
#   Remaining B:   87730
#   Agent Rewards:       [5.6 1.2 9. ]
#   Clay Rewards:       15.8
#   TOT Agent Rewards:       15.8
# Trail 0 Round 9081
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 6  0 10]
#   Remaining B:   87384
#   Agent Rewards:       [ 4.2  0.  10. ]
#   Clay Rewards:       14.2
#   TOT Agent Rewards:       14.2
# Trail 0 Round 9101
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 3  3 11]
#   Remaining B:   86993
#   Agent Rewards:       [ 2.1  1.8 11. ]
#   Clay Rewards:       15.6
#   TOT Agent Rewards:       14.899999999999999
# Trail 0 Round 9121
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 4  6 13]
#   Remaining B:   86611
#   Agent Rewards:       [ 2.8  3.6 13. ]
#   Clay Rewards:       19.4
#   TOT Agent Rewards:       19.4
# Trail 0 Round 9141
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 8  1 12]
#   Remaining B:   86251
#   Agent Rewards:       [ 5.6  0.6 12. ]
#   Clay Rewards:       18.2
#   TOT Agent Rewards:       18.2
# Trail 0 Round 9161
#   Agent prices:  [2, 1, 3]
#   Demand:        [9 3 8]
#   Remaining B:   85884
#   Agent Rewards:       [6.3 1.8 8. ]
#   Clay Rewards:       16.1
#   TOT Agent Rewards:       16.1
# Trail 0 Round 9181
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 3  3 12]
#   Remaining B:   85519
#   Agent Rewards:       [ 2.1  1.8 12. ]
#   Clay Rewards:       16.2
#   TOT Agent Rewards:       15.899999999999999
# Trail 0 Round 9201
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 6  3 10]
#   Remaining B:   85166
#   Agent Rewards:       [ 4.2  1.8 10. ]
#   Clay Rewards:       16.0
#   TOT Agent Rewards:       16.0
# Trail 0 Round 9221
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 7  1 10]
#   Remaining B:   84791
#   Agent Rewards:       [ 4.9  0.6 10. ]
#   Clay Rewards:       15.5
#   TOT Agent Rewards:       15.5
# Trail 0 Round 9241
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 8  4 12]
#   Remaining B:   84437
#   Agent Rewards:       [ 5.6  2.4 12. ]
#   Clay Rewards:       20.0
#   TOT Agent Rewards:       20.0
# Trail 0 Round 9261
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 5  3 11]
#   Remaining B:   84054
#   Agent Rewards:       [ 3.5  1.8 11. ]
#   Clay Rewards:       16.3
#   TOT Agent Rewards:       16.3
# Trail 0 Round 9281
#   Agent prices:  [2, 1, 3]
#   Demand:        [6 4 7]
#   Remaining B:   83705
#   Agent Rewards:       [4.2 2.4 7. ]
#   Clay Rewards:       13.6
#   TOT Agent Rewards:       13.6
# Trail 0 Round 9301
#   Agent prices:  [2, 1, 3]
#   Demand:        [5 3 8]
#   Remaining B:   83368
#   Agent Rewards:       [3.5 1.8 8. ]
#   Clay Rewards:       13.3
#   TOT Agent Rewards:       13.3
# Trail 0 Round 9321
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 5  2 10]
#   Remaining B:   83004
#   Agent Rewards:       [ 3.5  1.2 10. ]
#   Clay Rewards:       14.7
#   TOT Agent Rewards:       14.7
# Trail 0 Round 9341
#   Agent prices:  [2, 1, 3]
#   Demand:        [7 3 7]
#   Remaining B:   82659
#   Agent Rewards:       [4.9 1.8 7. ]
#   Clay Rewards:       13.7
#   TOT Agent Rewards:       13.7
# Trail 0 Round 9361
#   Agent prices:  [2, 1, 3]
#   Demand:        [5 5 9]
#   Remaining B:   82304
#   Agent Rewards:       [3.5 3.  9. ]
#   Clay Rewards:       15.5
#   TOT Agent Rewards:       15.5
# Trail 0 Round 9381
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 5  4 10]
#   Remaining B:   81934
#   Agent Rewards:       [ 3.5  2.4 10. ]
#   Clay Rewards:       15.9
#   TOT Agent Rewards:       15.9
# Trail 0 Round 9401
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 7  0 13]
#   Remaining B:   81554
#   Agent Rewards:       [ 4.9  0.  13. ]
#   Clay Rewards:       17.9
#   TOT Agent Rewards:       17.9
# Trail 0 Round 9421
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 5  3 12]
#   Remaining B:   81165
#   Agent Rewards:       [ 3.5  1.8 12. ]
#   Clay Rewards:       17.3
#   TOT Agent Rewards:       17.3
# Trail 0 Round 9441
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 8  3 10]
#   Remaining B:   80800
#   Agent Rewards:       [ 5.6  1.8 10. ]
#   Clay Rewards:       17.4
#   TOT Agent Rewards:       17.4
# Trail 0 Round 9461
#   Agent prices:  [2, 1, 3]
#   Demand:        [5 4 7]
#   Remaining B:   80453
#   Agent Rewards:       [3.5 2.4 7. ]
#   Clay Rewards:       12.9
#   TOT Agent Rewards:       12.9
# Trail 0 Round 9481
#   Agent prices:  [2, 1, 3]
#   Demand:        [10  4  5]
#   Remaining B:   80091
#   Agent Rewards:       [7.  2.4 5. ]
#   Clay Rewards:       14.4
#   TOT Agent Rewards:       14.4
# Trail 0 Round 9501
#   Agent prices:  [2, 1, 3]
#   Demand:        [7 3 5]
#   Remaining B:   79749
#   Agent Rewards:       [4.9 1.8 5. ]
#   Clay Rewards:       11.7
#   TOT Agent Rewards:       11.7
# Trail 0 Round 9521
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 5  4 10]
#   Remaining B:   79399
#   Agent Rewards:       [ 3.5  2.4 10. ]
#   Clay Rewards:       15.9
#   TOT Agent Rewards:       15.9
# Trail 0 Round 9541
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 6  3 13]
#   Remaining B:   79044
#   Agent Rewards:       [ 4.2  1.8 13. ]
#   Clay Rewards:       19.0
#   TOT Agent Rewards:       19.0
# Trail 0 Round 9561
#   Agent prices:  [2, 1, 3]
#   Demand:        [6 0 8]
#   Remaining B:   78688
#   Agent Rewards:       [4.2 0.  8. ]
#   Clay Rewards:       12.2
#   TOT Agent Rewards:       12.2
# Trail 0 Round 9581
#   Agent prices:  [2, 1, 3]
#   Demand:        [5 2 7]
#   Remaining B:   78315
#   Agent Rewards:       [3.5 1.2 7. ]
#   Clay Rewards:       11.7
#   TOT Agent Rewards:       11.7
# Trail 0 Round 9601
#   Agent prices:  [2, 1, 3]
#   Demand:        [11  3  7]
#   Remaining B:   77976
#   Agent Rewards:       [7.7 1.8 7. ]
#   Clay Rewards:       16.5
#   TOT Agent Rewards:       16.5
# Trail 0 Round 9621
#   Agent prices:  [2, 1, 3]
#   Demand:        [10  4 11]
#   Remaining B:   77611
#   Agent Rewards:       [ 7.   2.4 11. ]
#   Clay Rewards:       20.4
#   TOT Agent Rewards:       20.4
# Trail 0 Round 9641
#   Agent prices:  [2, 1, 3]
#   Demand:        [7 5 9]
#   Remaining B:   77247
#   Agent Rewards:       [4.9 3.  9. ]
#   Clay Rewards:       16.9
#   TOT Agent Rewards:       16.9
# Trail 0 Round 9661
#   Agent prices:  [2, 1, 3]
#   Demand:        [6 2 9]
#   Remaining B:   76911
#   Agent Rewards:       [4.2 1.2 9. ]
#   Clay Rewards:       14.399999999999999
#   TOT Agent Rewards:       14.399999999999999
# Trail 0 Round 9681
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 7  3 13]
#   Remaining B:   76555
#   Agent Rewards:       [ 4.9  1.8 13. ]
#   Clay Rewards:       19.7
#   TOT Agent Rewards:       19.7
# Trail 0 Round 9701
#   Agent prices:  [2, 1, 3]
#   Demand:        [6 5 7]
#   Remaining B:   76199
#   Agent Rewards:       [4.2 3.  7. ]
#   Clay Rewards:       14.2
#   TOT Agent Rewards:       14.2
# Trail 0 Round 9721
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 5  4 10]
#   Remaining B:   75857
#   Agent Rewards:       [ 3.5  2.4 10. ]
#   Clay Rewards:       16.0
#   TOT Agent Rewards:       15.9
# Trail 0 Round 9741
#   Agent prices:  [2, 1, 3]
#   Demand:        [8 3 9]
#   Remaining B:   75504
#   Agent Rewards:       [5.6 1.8 9. ]
#   Clay Rewards:       16.4
#   TOT Agent Rewards:       16.4
# Trail 0 Round 9761
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 8  3 11]
#   Remaining B:   75140
#   Agent Rewards:       [ 5.6  1.8 11. ]
#   Clay Rewards:       18.4
#   TOT Agent Rewards:       18.4
# Trail 0 Round 9781
#   Agent prices:  [2, 1, 3]
#   Demand:        [3 0 9]
#   Remaining B:   74789
#   Agent Rewards:       [2.1 0.  9. ]
#   Clay Rewards:       12.0
#   TOT Agent Rewards:       11.1
# Trail 0 Round 9801
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 3  4 13]
#   Remaining B:   74457
#   Agent Rewards:       [ 2.1  2.4 13. ]
#   Clay Rewards:       18.2
#   TOT Agent Rewards:       17.5
# Trail 0 Round 9821
#   Agent prices:  [2, 1, 3]
#   Demand:        [3 3 9]
#   Remaining B:   74106
#   Agent Rewards:       [2.1 1.8 9. ]
#   Clay Rewards:       14.0
#   TOT Agent Rewards:       12.899999999999999
# Trail 0 Round 9841
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 6  2 10]
#   Remaining B:   73745
#   Agent Rewards:       [ 4.2  1.2 10. ]
#   Clay Rewards:       15.399999999999999
#   TOT Agent Rewards:       15.399999999999999
# Trail 0 Round 9861
#   Agent prices:  [2, 1, 3]
#   Demand:        [6 2 8]
#   Remaining B:   73380
#   Agent Rewards:       [4.2 1.2 8. ]
#   Clay Rewards:       13.399999999999999
#   TOT Agent Rewards:       13.399999999999999
# Trail 0 Round 9881
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 6  3 12]
#   Remaining B:   73032
#   Agent Rewards:       [ 4.2  1.8 12. ]
#   Clay Rewards:       18.0
#   TOT Agent Rewards:       18.0
# Trail 0 Round 9901
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 4  1 11]
#   Remaining B:   72672
#   Agent Rewards:       [ 2.8  0.6 11. ]
#   Clay Rewards:       14.799999999999999
#   TOT Agent Rewards:       14.4
# Trail 0 Round 9921
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 6  1 13]
#   Remaining B:   72310
#   Agent Rewards:       [ 4.2  0.6 13. ]
#   Clay Rewards:       17.799999999999997
#   TOT Agent Rewards:       17.799999999999997
# Trail 0 Round 9941
#   Agent prices:  [2, 1, 3]
#   Demand:        [4 2 7]
#   Remaining B:   71961
#   Agent Rewards:       [2.8 1.2 7. ]
#   Clay Rewards:       11.0
#   TOT Agent Rewards:       11.0
# Trail 0 Round 9961
#   Agent prices:  [2, 1, 3]
#   Demand:        [ 6  1 12]
#   Remaining B:   71613
#   Agent Rewards:       [ 4.2  0.6 12. ]
#   Clay Rewards:       16.799999999999997
#   TOT Agent Rewards:       16.799999999999997
# Trail 0 Round 9981
#   Agent prices:  [2, 1, 3]
#   Demand:        [7 3 8]
#   Remaining B:   71254
#   Agent Rewards:       [4.9 1.8 8. ]
#   Clay Rewards:       14.7
#   TOT Agent Rewards:       14.7
# === Final Results Trail 0 ===
# Total agent reward:       150802.60
# Deterministic clairvoyant reward: 153135.70
# Total regret:             2333.10
# Average regret ratio:     0.277
# === Final Results Trail 1 ===
# Total agent reward:       151159.90
# Deterministic clairvoyant reward: 153522.00
# Total regret:             2362.10
# Average regret ratio:     0.288
# === Final Results Trail 2 ===
# Total agent reward:       151550.40
# Deterministic clairvoyant reward: 153888.50
# Total regret:             2338.10
# Average regret ratio:     0.282
# === Final Results Trail 3 ===
# Total agent reward:       151029.60
# Deterministic clairvoyant reward: 153324.30
# Total regret:             2294.70
# Average regret ratio:     0.290
# === Final Results Trail 4 ===
# Total agent reward:       151296.20
# Deterministic clairvoyant reward: 153615.20
# Total regret:             2319.00
# Average regret ratio:     0.281
# === Final Results Trail 5 ===
# Total agent reward:       151403.40
# Deterministic clairvoyant reward: 153793.60
# Total regret:             2390.20
# Average regret ratio:     0.287
# === Final Results Trail 6 ===
# Total agent reward:       151624.40
# Deterministic clairvoyant reward: 153902.30
# Total regret:             2277.90
# Average regret ratio:     0.278
# === Final Results Trail 7 ===
# Total agent reward:       151393.00
# Deterministic clairvoyant reward: 153638.00
# Total regret:             2245.00
# Average regret ratio:     0.286
# === Final Results Trail 8 ===
# Total agent reward:       151540.70
# Deterministic clairvoyant reward: 153803.10
# Total regret:             2262.40
# Average regret ratio:     0.265
# === Final Results Trail 9 ===
# Total agent reward:       151114.20
# Deterministic clairvoyant reward: 153386.70
# Total regret:             2272.50
# Average regret ratio:     0.278
# === Final Results Trail 10 ===
# Total agent reward:       151010.90
# Deterministic clairvoyant reward: 153339.40
# Total regret:             2328.50
# Average regret ratio:     0.283
# === Final Results Trail 11 ===
# Total agent reward:       150895.50
# Deterministic clairvoyant reward: 153154.50
# Total regret:             2259.00
# Average regret ratio:     0.287
# === Final Results Trail 12 ===
# Total agent reward:       151132.60
# Deterministic clairvoyant reward: 153497.30
# Total regret:             2364.70
# Average regret ratio:     0.299
# === Final Results Trail 13 ===
# Total agent reward:       151097.50
# Deterministic clairvoyant reward: 153445.50
# Total regret:             2348.00
# Average regret ratio:     0.281
# === Final Results Trail 14 ===
# Total agent reward:       151043.60
# Deterministic clairvoyant reward: 153404.00
# Total regret:             2360.40
# Average regret ratio:     0.294

# %%
print("=== Final Results Overall ===")
print(f"Total agent reward:       {overtrials_agentreward:.2f}")
print(f"Deterministic clairvoyant reward: {overtrials_clay:.2f}")
print(f"Total regret:             {overtrials_regret:.2f}")
print(f"Average regret ratio:     {overtrials_avgregret / n_trials:.3f}")
# Out:
# === Final Results Overall ===
# Total agent reward:       2268094.50
# Deterministic clairvoyant reward: 2302850.10
# Total regret:             34755.60
# Average regret ratio:     0.284

# %%
import seaborn as sns
sns.set(style="whitegrid")

plt.figure(figsize=(8,5))

# Plot with a thicker line, smaller markers, and a nice color
plt.plot(range(1, T+1), avg_regret_ratio_per_round,
         color="#1f77b4",  # a modern blue
         linewidth=2.5,
         marker='o',
         markersize=1,      # smaller dots
         alpha=0.8)         # slight transparency for smooth look

plt.xlabel("Round", fontsize=14)
plt.ylabel("Average Regret Ratio", fontsize=14)
plt.title("Average Cumulative Regret Ratio Over All Trials", fontsize=16, weight='bold')
plt.grid(True, linestyle='--', alpha=0.5)  # dashed grid, subtle
plt.tight_layout()
plt.show()

# %%
import seaborn as sns
sns.set(style="whitegrid")

plt.figure(figsize=(8,5))

# Plot with a thicker line, smaller markers, and a nice color
plt.plot(range(1, T+1), avg_regret,
         color="#1f77b4",  # a modern blue
         linewidth=1.5,
         marker='o',
         markersize=1,      # smaller dots
         alpha=0.8)         # slight transparency for smooth look

plt.xlabel("Round", fontsize=14)
plt.ylabel("Average Cumulative Regret", fontsize=14)
plt.title("Average Cumulative Regret Over All Trials", fontsize=16, weight='bold')
plt.grid(True, linestyle='--', alpha=0.5)  # dashed grid, subtle
plt.tight_layout()
plt.show()

# %%
import seaborn as sns
sns.set(style="whitegrid")

plt.figure(figsize=(8,5))

# Plot with a thicker line, smaller markers, and a nice color
plt.plot(range(1, T+1), avg_inventory_per_trial,
         color="#1f77b4",  # a modern blue
         linewidth=1.5,
         marker='o',
         markersize=1,      # smaller dots
         alpha=0.8)         # slight transparency for smooth look

plt.xlabel("Round", fontsize=14)
plt.ylabel("Average Inventory", fontsize=14)
plt.title("Average Inventory Over All Trials", fontsize=16, weight='bold')
plt.grid(True, linestyle='--', alpha=0.5)  # dashed grid, subtle
plt.tight_layout()
plt.show()

# %%
b_pairs = np.zeros((num_products, 2))

for i in range(num_products):
   b_pairs[i,0] = i
   b_pairs[i,1] = last[i]

alg_result = list(b_pairs)
alg_res_int = [(int(i[0]), int(i[1])) for i in alg_result]

plot_weighted_matching_custom(alg_res_int, W, products, prices)
